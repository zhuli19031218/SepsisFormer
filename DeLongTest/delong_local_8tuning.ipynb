# %%
# main_deep_learning_trainer.py
import os
import argparse
import time
import torch
import torch.nn as nn
import numpy as np
from sklearn.metrics import roc_auc_score, accuracy_score
import pandas as pd

from Transformer import Transformer # 假设其他模型导入也正确
from model_LSTM import Lstm
from model_GRU import GRU
from model_gpt import GPT
import warnings
import sys
from data_utils import load_presplit_data_from_dir
warnings.filterwarnings("ignore", message="Implicit dimension choice for log_softmax has been deprecated.", category=UserWarning, module="torch.nn.modules.module")
# 假设你的 NMTCritierion 在 utilis_data.py 中
# 你需要确保这个导入路径是正确的，或者将 NMTCritierion 的定义复制过来

try:
    from utilis_data import NMTCritierion
    HAS_NMTCriterion = True
except ImportError:
    print("警告: 未找到 utilis_data.NMTCritierion。将使用 nn.CrossEntropyLoss。")
    HAS_NMTCriterion = False
    NMTCritierion = None # 占位

def parse_arguments():
    parser = argparse.ArgumentParser(description="深度学习模型训练脚本 (从预分割数据加载)")
    parser.add_argument('--presplit_data_dir', type=str, required=True,
                        help="包含预分割CSV文件的目录路径。")
    parser.add_argument('--label_column', type=str, default="dead", help="CSV文件中标签列的名称。")
    parser.add_argument('--device', type=str, default='cuda' if torch.cuda.is_available() else 'cpu', help='指定运行设备。')
    parser.add_argument('--seed', type=int, default=42, help='模型训练过程中的随机种子。') # 与原始脚本的seed一致
    
    parser.add_argument('--load_pretrained_model', type=str, default=None,
                    help="预训练模型文件 (.pth) 的路径。如果提供，则加载权重。")
    parser.add_argument('--freeze_backbone', action='store_true',
                    help="如果加载预训练模型，是否冻结骨干网络参数（除分类头外）。")
    
    parser.add_argument('--model_name', type=str, default="Lstm", choices=["Transformer", "Lstm", "GRU", "GPT"], help='选择模型架构。')
    # Transformer specific (Lstm用不到这些，但argparse会处理)
    parser.add_argument('--model_dim', type=int, default=128, help='Transformer/GPT 内部维度。')
    parser.add_argument('--depth', type=int, default=8, help='Transformer 深度。')
    parser.add_argument('--num_heads', type=int, default=8, help='Transformer/GPT 注意力头数。')
    
    # 通用或特定模型
    parser.add_argument('--drop_ratio', type=float, default=0.1, help='模型中的 Dropout 比率。')
    parser.add_argument('--num_layers', type=int, default=2, help="GRU/GPT 的层数 (Lstm层数是固定的)。") # Lstm不直接用这个
    
    parser.add_argument('--lr', type=float, default=5e-4, help='初始学习率。')
    parser.add_argument('--epochs', type=int, default=800, help='训练的总轮数。')
    parser.add_argument('--batch_size', type=int, default=5000, help='数据加载的批量大小。')
    
    parser.add_argument('--output_base_dir', type=str, default="./dl_model_outputs_replication",
                        help="保存输出的主目录。")
    parser.add_argument('--experiment_tag', type=str, default="", help="实验的额外标签。")
    opts = parser.parse_args()
    return opts

def initialize_model(args, num_features):
    # 首先，根据模型名称和参数实例化模型
    if args.model_name == "Lstm":
        print(f"初始化 Lstm模型: factors={num_features}, batch_size={args.batch_size}, drop_ratio={args.drop_ratio}, device={args.device}")
        model = Lstm(
            factors=num_features,
            batch_size=args.batch_size,
            drop_ratio=args.drop_ratio,
            device=args.device
        )
    elif args.model_name == "Transformer":
        print(f"初始化 Transformer模型: input_dim={num_features}, model_dim={args.model_dim}, depth={args.depth}, num_heads={args.num_heads}, drop_ratio={args.drop_ratio}")
        # 确保 Transformer 构造函数与你的 Transformer.py 一致
        model = Transformer(
            input_dim=num_features,
            model_dim=args.model_dim,
            depth=args.depth,
            num_heads=args.num_heads,
            drop_ratio=args.drop_ratio
            # qkv_bias=True, # 根据你的Transformer.py添加其他必要参数
            # attn_drop_ratio=args.drop_ratio,
            # drop_path_ratio=args.drop_path_ratio if hasattr(args, 'drop_path_ratio') else 0.1,
        )
    elif args.model_name == "GRU":
        print(f"初始化 GRU模型: factors={num_features}, batch_size={args.batch_size}, num_layers={args.num_layers}, drop_ratio={args.drop_ratio}, device={args.device}")
        model = GRU(
            factors=num_features,
            batch_size=args.batch_size,
            num_layers=args.num_layers,
            drop_ratio=args.drop_ratio,
            device=args.device
        )
    elif args.model_name == "GPT":
        # 严格遵循原始 train.py 中 GPT 的实例化逻辑
        gpt_actual_input_dim = num_features
        gpt_internal_hidden_dim = num_features # 模型内部工作维度，为了匹配原始 hidden_dim=factors
        gpt_internal_num_heads = 4           # 硬编码自原始 train.py
        gpt_internal_ff_expansion_factor = 128 # 硬编码自原始 train.py

        print(f"初始化 GPT模型 (尝试严格复现原始 train.py 实例化):")
        print(f"  actual_input_dim: {gpt_actual_input_dim}")
        print(f"  hidden_dim: {gpt_internal_hidden_dim}")
        print(f"  num_heads: {gpt_internal_num_heads}")
        print(f"  num_layers: {args.num_layers}")
        print(f"  dropout: {args.drop_ratio}")
        print(f"  ff_expansion_factor: {gpt_internal_ff_expansion_factor}")

        # 确保你的 model_gpt.py 中的 GPT 类 __init__ 签名是这样的：
        # def __init__(self, actual_input_dim, hidden_dim, num_heads, num_layers,
        #              ff_expansion_factor, dropout, max_seq_len=512, device='cuda'):
        # 并且它内部正确使用了 actual_input_dim 来创建一个投影层到 hidden_dim
        model = GPT(
            actual_input_dim=gpt_actual_input_dim,
            hidden_dim=gpt_internal_hidden_dim,
            num_heads=gpt_internal_num_heads,
            num_layers=args.num_layers,
            ff_expansion_factor=gpt_internal_ff_expansion_factor,
            dropout=args.drop_ratio,
            device=args.device
            # max_seq_len 如果需要，也应传递
        )
    else:
        raise ValueError(f"未知的模型名称: {args.model_name}")

    # 将模型移动到设备
    model = model.to(args.device)

    # --- 加载预训练权重逻辑 ---
    if args.load_pretrained_model and hasattr(args, 'load_pretrained_model') and args.load_pretrained_model is not None: # 检查参数是否存在且非None
        if os.path.exists(args.load_pretrained_model):
            print(f"\n加载预训练权重从: {args.load_pretrained_model}")
            try:
                pretrained_state_dict = torch.load(args.load_pretrained_model, map_location=args.device)

                # 处理常见的state_dict包装方式
                if isinstance(pretrained_state_dict, dict):
                    if 'state_dict' in pretrained_state_dict:
                        pretrained_state_dict = pretrained_state_dict['state_dict']
                    elif 'model_state_dict' in pretrained_state_dict:
                        pretrained_state_dict = pretrained_state_dict['model_state_dict']
                    # 如果直接就是 state_dict，则无需处理

                current_model_dict = model.state_dict()

                # --- 确定分类头的名称 ---
                # 这需要根据你每个模型的具体实现来确定
                # 假设 Transformer 的分类头是 'MLP' (基于你原始的 Transformer.py 中的 self.MLP)
                # 假设 Lstm, GRU, GPT 的分类头都叫做 'head' (基于常见的命名)
                # 你需要根据实际情况修改这些名称！
                classifier_head_keyword = None
                if args.model_name == "Transformer":
                    classifier_head_keyword = "MLP." # 加点号确保是模块名的一部分
                elif args.model_name in ["Lstm", "GRU", "GPT"]:
                    # 检查你的模型定义中分类头的真实名称
                    # 假设在这些模型中，最终的线性层或包含最终线性层的Sequential块叫做 'head'
                    if hasattr(model, 'head'):
                        classifier_head_keyword = "head."
                    else:
                        print(f"警告: 模型 {args.model_name} 没有找到名为 'head' 的属性，无法准确排除分类头权重。请检查模型定义。")
                
                if classifier_head_keyword is None and args.model_name != "Transformer": # Transformer 有特例
                     print(f"警告: 未能确定模型 {args.model_name} 的分类头名称，将尝试加载所有匹配的权重。这可能导致分类头也被预训练权重覆盖。")


                state_dict_to_load = {}
                weights_loaded_count = 0
                weights_skipped_shape_mismatch = 0
                weights_skipped_classifier = 0

                for k, v_pretrained in pretrained_state_dict.items():
                    load_this_weight = True
                    if classifier_head_keyword: # 如果我们定义了分类头的关键词
                        if k.startswith(classifier_head_keyword):
                            weights_skipped_classifier += 1
                            load_this_weight = False # 不加载分类头的权重
                    
                    if load_this_weight:
                        if k in current_model_dict:
                            v_current = current_model_dict[k]
                            if v_current.shape == v_pretrained.shape:
                                state_dict_to_load[k] = v_pretrained
                                weights_loaded_count += 1
                            else:
                                print(f"  形状不匹配，跳过加载权重 {k}: 预训练 {v_pretrained.shape}, 当前 {v_current.shape}")
                                weights_skipped_shape_mismatch += 1
                        # else: # 预训练模型中有，但当前模型没有的键，通常可以忽略
                        #     print(f"  权重 {k} 在预训练模型中存在，但在当前模型中不存在，跳过。")
                
                if not state_dict_to_load:
                    print("警告: 没有从预训练模型中找到可加载的匹配权重（非分类头部分）。")
                else:
                    print(f"将从预训练模型加载 {weights_loaded_count} 个参数组。")
                    if weights_skipped_classifier > 0:
                        print(f"  跳过了 {weights_skipped_classifier} 个分类头相关的参数组。")
                    if weights_skipped_shape_mismatch > 0:
                        print(f"  因形状不匹配跳过了 {weights_skipped_shape_mismatch} 个参数组。")
                    
                    current_model_dict.update(state_dict_to_load)
                    # 使用 strict=False 允许当前模型中存在预训练模型没有的键（例如新初始化的分类头）
                    # 也允许预训练模型中存在当前模型没有的键（虽然我们已经通过 k in current_model_dict 过滤了一部分）
                    model.load_state_dict(current_model_dict, strict=False)
                    print("预训练权重加载完成。分类头（如果存在且未被加载）保持其原有初始化。")

                # --- 冻结骨干网络参数 ---
                if args.freeze_backbone and hasattr(args, 'freeze_backbone') and args.freeze_backbone:
                    print("冻结骨干网络参数...")
                    num_frozen = 0
                    num_trainable = 0
                    for name, param in model.named_parameters():
                        freeze_this_param = True
                        if classifier_head_keyword: # 如果我们定义了分类头的关键词
                            if name.startswith(classifier_head_keyword):
                                freeze_this_param = False # 不冻结分类头的参数
                        
                        if freeze_this_param:
                            param.requires_grad = False
                            num_frozen +=1
                        else:
                            param.requires_grad = True # 确保分类头是可训练的
                            print(f"  分类头参数 '{name}' 将保持可训练。")
                            num_trainable +=1
                    print(f"  已冻结 {num_frozen} 组参数。")
                    print(f"  保持可训练 {num_trainable} 组参数 (主要是分类头)。")
            except Exception as e:
                print(f"错误: 加载预训练权重时发生异常: {e}")
                print("将从头开始训练模型。")
        else:
            print(f"警告: 预训练模型文件未找到: {args.load_pretrained_model}。将从头开始训练。")
    else:
        print("未提供预训练模型路径，或未启用预训练加载。模型将从头开始训练。")
        
    return model

def prepare_input_for_model(batch_data, model_name, device):
    # 这个函数与原始 _prepare_input 逻辑一致
    input_features = batch_data['data'].to(device, non_blocking=True)
    targets = batch_data['target'].to(device, non_blocking=True)
    if input_features.ndim == 2:
        input_features = input_features.unsqueeze(1)
    if model_name in ["Lstm", "GRU"]:
        if input_features.shape[1] == 1:
            input_features = input_features.permute(1, 0, 2)
    return input_features, targets

def main():
    args = parse_arguments()

    torch.manual_seed(args.seed)
    np.random.seed(args.seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(args.seed)

    print("\n--- 参数配置 ---")
    for arg, value in sorted(vars(args).items()):
        print(f"  {arg}: {value}")
    print("-" * 30)

    current_time = time.strftime("%Y%m%d-%H%M%S")
    data_source_tag = os.path.basename(os.path.normpath(args.presplit_data_dir))
    experiment_name_parts = [args.model_name, data_source_tag.replace('_split','')]
    if args.experiment_tag: experiment_name_parts.append(args.experiment_tag)
    experiment_name_parts.append(f"trainseed{args.seed}")
    experiment_name_parts.append(current_time)
    experiment_run_name = "_".join(experiment_name_parts)
    experiment_output_dir = os.path.join(args.output_base_dir, experiment_run_name)
    os.makedirs(experiment_output_dir, exist_ok=True)
    print(f"所有输出将保存到: {experiment_output_dir}")

    train_loader, test_loader, n_train, n_test, num_features = load_presplit_data_from_dir(
        presplit_data_dir=args.presplit_data_dir, batch_size=args.batch_size,
        label_column=args.label_column
    )
    print(f"成功从预分割目录加载数据: {args.presplit_data_dir}，特征数: {num_features}")

    model = initialize_model(args, num_features)
    print("\n--- 模型结构 ---")
    print(model)
    print("-" * 30)

    # 严格按照原始 train.py 的优化器设置
    optimizer = torch.optim.Adam(model.parameters(), lr=args.lr, weight_decay=0) # 原始代码 weight_decay=0
    print(f"优化器: Adam, LR: {args.lr}, Weight Decay: 0")

    # 严格按照原始 train.py 的损失函数设置
    if HAS_NMTCriterion:
        label_smoothing_value = 0.3
        criterion = NMTCritierion(label_smoothing=label_smoothing_value).to(args.device)
        print(f"损失函数: NMTCritierion (标签平滑: {label_smoothing_value})")
    else:
        criterion = nn.CrossEntropyLoss().to(args.device)
        print(f"损失函数: nn.CrossEntropyLoss (因为 NMTCritierion 未找到)")


    best_test_auc = 0.0
    best_model_epoch = -1
    final_test_labels_for_delong = None
    final_test_probs_for_delong = None

    print("\n--- 开始训练 ---")
    for epoch in range(args.epochs):
        epoch_start_time = time.time()
        model.train()
        total_train_loss = 0
        for batch_idx, batch in enumerate(train_loader):
            input_features, targets = prepare_input_for_model(batch, args.model_name, args.device)
            optimizer.zero_grad()
            outputs = model(input_features) # outputs 是概率 (因为Lstm模型末尾有Softmax)

            
            if isinstance(criterion, nn.CrossEntropyLoss):
              
                if HAS_NMTCriterion and isinstance(criterion, NMTCritierion):
                    loss = criterion(outputs, targets) # 假设 NMTCritierion 能处理概率或内部有log
                elif isinstance(criterion, nn.CrossEntropyLoss):
                    # 这里是个问题点：CELoss期望logits，但Lstm输出概率
                    # 我们需要 log(probabilities) 作为 CELoss 的近似输入（但不完全等同于logits）
                    # 或者，更标准的是，Lstm模型不应有最后的Softmax
                    print("警告: Lstm模型输出概率，但nn.CrossEntropyLoss期望logits。结果可能不准确。建议修改Lstm模型移除末尾Softmax。")
                    loss = criterion(torch.log(outputs + 1e-9), targets) # 加一个小值避免log(0)
                else: # 其他自定义损失
                    loss = criterion(outputs, targets)

            else: # 默认情况，比如就是 NMTCritierion
                 loss = criterion(outputs, targets)


            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()
        avg_train_loss = total_train_loss / len(train_loader)

        model.eval()
        current_epoch_test_targets_list = []
        current_epoch_test_probs_list = []

        with torch.no_grad():
            for batch in test_loader:
                input_features, targets = prepare_input_for_model(batch, args.model_name, args.device)
                outputs_probs = model(input_features) # Lstm 直接输出概率

                positive_class_probs = outputs_probs[:, 1]
                current_epoch_test_targets_list.extend(targets.cpu().numpy())
                current_epoch_test_probs_list.extend(positive_class_probs.cpu().numpy())

        epoch_targets_np = np.array(current_epoch_test_targets_list)
        epoch_probs_np = np.array(current_epoch_test_probs_list)
        epoch_preds_np = (epoch_probs_np >= 0.5).astype(int)

        test_acc = accuracy_score(epoch_targets_np, epoch_preds_np)
        test_auc = 0.0
        try:
            if len(np.unique(epoch_targets_np)) > 1 and len(epoch_probs_np) > 0:
                test_auc = roc_auc_score(epoch_targets_np, epoch_probs_np)
            else:
                print(f"警告: Epoch {epoch+1} 测试集标签种类不足或概率为空, AUC设为0.0。")
        except ValueError as e:
            print(f"警告: Epoch {epoch+1} 计算AUC时出错 ({e}), AUC设为0.0。")

        epoch_duration = time.time() - epoch_start_time


        if test_auc > best_test_auc:
            best_test_auc = test_auc
            best_model_epoch = epoch + 1
            final_test_labels_for_delong = epoch_targets_np.copy()
            final_test_probs_for_delong = epoch_probs_np.copy()
            torch.save(model.state_dict(), os.path.join(experiment_output_dir, "best_auc_model.pth"))
            print(f"  * New best Test AUC: {best_test_auc:.4f} at Epoch {best_model_epoch}. Model and DeLong data updated.")
            print(f"Epoch [{epoch+1:03d}/{args.epochs:03d}] | "
              f"Train Loss: {avg_train_loss:.4f} | Test Acc: {test_acc:.4f} | "
              f"Test AUC: {test_auc:.4f} | Time: {epoch_duration:.2f}s")
    print("\n--- 训练完成 ---")
    # ... (后续的保存DeLong文件和参数摘要逻辑与之前版本相同) ...
    if best_model_epoch != -1:
        print(f"最佳测试集 AUC: {best_test_auc:.4f} (在 Epoch {best_model_epoch} 获得)")
        if final_test_labels_for_delong is not None and final_test_probs_for_delong is not None:
            np.save(os.path.join(experiment_output_dir, f"{args.model_name}_test_labels_best_auc.npy"), final_test_labels_for_delong)
            np.save(os.path.join(experiment_output_dir, f"{args.model_name}_test_probs_best_auc.npy"), final_test_probs_for_delong)
            print(f"为DeLong检验准备的最终测试集标签和概率已保存.")
            np.save(os.path.join(experiment_output_dir, "test_labels.npy"), final_test_labels_for_delong)
            np.save(os.path.join(experiment_output_dir, "test_probabilities.npy"), final_test_probs_for_delong)
            print(f"同时保存为通用文件名: test_labels.npy, test_probabilities.npy")
    else:
        print("没有在训练过程中记录到有效的最佳AUC模型。")

    args_dict = vars(args)
    args_dict['num_input_features'] = num_features
    args_dict['best_test_auc_achieved'] = best_test_auc
    args_dict['best_model_epoch'] = best_model_epoch
    args_df = pd.DataFrame([args_dict])
    args_df.to_csv(os.path.join(experiment_output_dir, "training_args_summary.csv"), index=False)
    print(f"训练参数和摘要已保存。")



import sys # 确保导入sys模块



if __name__ == '__main__':
    # --- 模拟命令行参数: 测试 Transformer 在 8因子 MIMIC-IV 数据上 (带预训练) ---
    PRETRAINED_MODEL_PATH = "/mnt/public/home/zhijiangwan/sepsisformer/sepsisformer/model2/dl_model_outputs_replication/Transformer_mimic3_eICU_8_factors_mimic3eICU-8f-transformer-replication_trainseed42_20250610-041619/best_auc_model.pth" # 你的预训练模型路径

    sys.argv = [
        'my_script_name_in_notebook.py', # 脚本名占位符
        # --- 使用你已有的目录名 ---
        '--presplit_data_dir', './temp_data_utils_logs/local_8_factors_split', # 8因子 Local 预分割数据目录
        '--model_name', 'Transformer',                                       # 模型名称
        # --- Transformer 特定参数 ---
        '--model_dim', '128',       # Transformer 内部维度
        '--depth', '8',             # Transformer 深度 (block数量)
        '--num_heads', '8',         # Transformer 注意力头数
        '--drop_ratio', '0.1',      # Dropout 比率 (与原始摘要一致)
        # '--drop_path_ratio', '0.1', # 如果你的Transformer类使用它
        # --- 通用参数 (严格参考你提供的原始摘要 for local 8-factor Transformer) ---
        '--lr', '0.0005',           # 学习率 (来自你提供的摘要)
        '--epochs', '3500',         # Epochs (来自你提供的摘要)
        '--batch_size', '5000',     # 批量大小
        '--output_base_dir', './dl_model_outputs_replication', # 输出基础目录
        '--experiment_tag', 'local-8f-transformer-replication', # 实验标签
        '--seed', '42',             # 随机种子
        '--device', 'cuda',         # 如果可用，使用cuda
        '--label_column', 'dead',   # 标签列名
        '--load_pretrained_model', PRETRAINED_MODEL_PATH,
        # '--num_layers', '2',      # 对于Transformer，depth参数更相关
        # --- 这次不加载预训练模型，所以不需要 --load_pretrained_model ---
    ]
    main()
# Out:
# --- 参数配置 ---
#   batch_size: 5000
#   depth: 8
#   device: cuda
#   drop_ratio: 0.1
#   epochs: 3500
#   experiment_tag: local-8f-transformer-replication
#   freeze_backbone: False
#   label_column: dead
#   load_pretrained_model: /mnt/public/home/zhijiangwan/sepsisformer/sepsisformer/model2/dl_model_outputs_replication/Transformer_mimic3_eICU_8_factors_mimic3eICU-8f-transformer-replication_trainseed42_20250610-041619/best_auc_model.pth
#   lr: 0.0005
#   model_dim: 128
#   model_name: Transformer
#   num_heads: 8
#   num_layers: 2
#   output_base_dir: ./dl_model_outputs_replication
#   presplit_data_dir: ./temp_data_utils_logs/local_8_factors_split
#   seed: 42
# ------------------------------
# 所有输出将保存到: ./dl_model_outputs_replication/Transformer_local_8_factors_local-8f-transformer-replication_trainseed42_20250610-064016
# 从预分割文件加载数据:
#   训练数据: ./temp_data_utils_logs/local_8_factors_split/split_train_data_seed256.csv
#   测试数据: ./temp_data_utils_logs/local_8_factors_split/split_test_data_seed256.csv
#   - 特征数量: 8
#   - 训练样本数: 435
#   - 测试样本数: 187
# 成功从预分割目录加载数据: ./temp_data_utils_logs/local_8_factors_split，特征数: 8
# 初始化 Transformer模型: input_dim=8, model_dim=128, depth=8, num_heads=8, drop_ratio=0.1
#
# 加载预训练权重从: /mnt/public/home/zhijiangwan/sepsisformer/sepsisformer/model2/dl_model_outputs_replication/Transformer_mimic3_eICU_8_factors_mimic3eICU-8f-transformer-replication_trainseed42_20250610-041619/best_auc_model.pth
# 将从预训练模型加载 102 个参数组。
#   跳过了 4 个分类头相关的参数组。
# 预训练权重加载完成。分类头（如果存在且未被加载）保持其原有初始化。
#
# --- 模型结构 ---
# Transformer(
#   (emmb): Sequential(
#     (0): Linear(in_features=8, out_features=128, bias=True)
#     (1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (2): ReLU()
#     (3): Dropout(p=0.1, inplace=False)
#   )
#   (backbone): Sequential(
#     (0): Block(
#       (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=128, out_features=3072, bias=True)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#         (proj): Linear(in_features=1024, out_features=128, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (FFN): FFN(
#         (fc1): Linear(in_features=128, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=768, out_features=128, bias=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (1): Block(
#       (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=128, out_features=3072, bias=True)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#         (proj): Linear(in_features=1024, out_features=128, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath()
#       (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (FFN): FFN(
#         (fc1): Linear(in_features=128, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=768, out_features=128, bias=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (2): Block(
#       (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=128, out_features=3072, bias=True)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#         (proj): Linear(in_features=1024, out_features=128, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath()
#       (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (FFN): FFN(
#         (fc1): Linear(in_features=128, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=768, out_features=128, bias=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (3): Block(
#       (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=128, out_features=3072, bias=True)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#         (proj): Linear(in_features=1024, out_features=128, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath()
#       (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (FFN): FFN(
#         (fc1): Linear(in_features=128, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=768, out_features=128, bias=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (4): Block(
#       (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=128, out_features=3072, bias=True)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#         (proj): Linear(in_features=1024, out_features=128, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath()
#       (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (FFN): FFN(
#         (fc1): Linear(in_features=128, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=768, out_features=128, bias=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (5): Block(
#       (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=128, out_features=3072, bias=True)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#         (proj): Linear(in_features=1024, out_features=128, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath()
#       (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (FFN): FFN(
#         (fc1): Linear(in_features=128, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=768, out_features=128, bias=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (6): Block(
#       (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=128, out_features=3072, bias=True)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#         (proj): Linear(in_features=1024, out_features=128, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath()
#       (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (FFN): FFN(
#         (fc1): Linear(in_features=128, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=768, out_features=128, bias=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (7): Block(
#       (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=128, out_features=3072, bias=True)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#         (proj): Linear(in_features=1024, out_features=128, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath()
#       (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (FFN): FFN(
#         (fc1): Linear(in_features=128, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=768, out_features=128, bias=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (MLP): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=64, out_features=2, bias=True)
#   )
# )
# ------------------------------
# 优化器: Adam, LR: 0.0005, Weight Decay: 0
# 损失函数: NMTCritierion (标签平滑: 0.3)
#
# --- 开始训练 ---
# /tmp/ipykernel_991/2346090114.py:135: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pretrained_state_dict = torch.load(args.load_pretrained_model, map_location=args.device)
# /mnt/public/home/zhijiangwan/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
#   * New best Test AUC: 0.6761 at Epoch 1. Model and DeLong data updated.
# Epoch [001/3500] | Train Loss: 34.9508 | Test Acc: 0.6524 | Test AUC: 0.6761 | Time: 0.14s
#   * New best Test AUC: 0.7095 at Epoch 2. Model and DeLong data updated.
# Epoch [002/3500] | Train Loss: 34.7374 | Test Acc: 0.6684 | Test AUC: 0.7095 | Time: 0.04s
#   * New best Test AUC: 0.7111 at Epoch 6. Model and DeLong data updated.
# Epoch [006/3500] | Train Loss: 31.5644 | Test Acc: 0.6524 | Test AUC: 0.7111 | Time: 0.04s
#   * New best Test AUC: 0.7121 at Epoch 13. Model and DeLong data updated.
# Epoch [013/3500] | Train Loss: 31.2590 | Test Acc: 0.6684 | Test AUC: 0.7121 | Time: 0.04s
#   * New best Test AUC: 0.7131 at Epoch 14. Model and DeLong data updated.
# Epoch [014/3500] | Train Loss: 31.2811 | Test Acc: 0.6684 | Test AUC: 0.7131 | Time: 0.04s
#   * New best Test AUC: 0.7151 at Epoch 15. Model and DeLong data updated.
# Epoch [015/3500] | Train Loss: 31.9912 | Test Acc: 0.6791 | Test AUC: 0.7151 | Time: 0.04s
#   * New best Test AUC: 0.7203 at Epoch 17. Model and DeLong data updated.
# Epoch [017/3500] | Train Loss: 31.3306 | Test Acc: 0.6738 | Test AUC: 0.7203 | Time: 0.04s
#   * New best Test AUC: 0.7209 at Epoch 50. Model and DeLong data updated.
# Epoch [050/3500] | Train Loss: 27.9859 | Test Acc: 0.6898 | Test AUC: 0.7209 | Time: 0.03s
#   * New best Test AUC: 0.7211 at Epoch 59. Model and DeLong data updated.
# Epoch [059/3500] | Train Loss: 28.0483 | Test Acc: 0.6791 | Test AUC: 0.7211 | Time: 0.04s
#   * New best Test AUC: 0.7240 at Epoch 60. Model and DeLong data updated.
# Epoch [060/3500] | Train Loss: 27.6413 | Test Acc: 0.7059 | Test AUC: 0.7240 | Time: 0.04s
#   * New best Test AUC: 0.7298 at Epoch 91. Model and DeLong data updated.
# Epoch [091/3500] | Train Loss: 25.9046 | Test Acc: 0.6898 | Test AUC: 0.7298 | Time: 0.03s
#   * New best Test AUC: 0.7299 at Epoch 92. Model and DeLong data updated.
# Epoch [092/3500] | Train Loss: 26.1319 | Test Acc: 0.6898 | Test AUC: 0.7299 | Time: 0.03s
#   * New best Test AUC: 0.7308 at Epoch 95. Model and DeLong data updated.
# Epoch [095/3500] | Train Loss: 25.4554 | Test Acc: 0.6845 | Test AUC: 0.7308 | Time: 0.03s
#   * New best Test AUC: 0.7320 at Epoch 96. Model and DeLong data updated.
# Epoch [096/3500] | Train Loss: 25.6957 | Test Acc: 0.6952 | Test AUC: 0.7320 | Time: 0.04s
#   * New best Test AUC: 0.7334 at Epoch 98. Model and DeLong data updated.
# Epoch [098/3500] | Train Loss: 26.0018 | Test Acc: 0.6791 | Test AUC: 0.7334 | Time: 0.04s
#   * New best Test AUC: 0.7348 at Epoch 116. Model and DeLong data updated.
# Epoch [116/3500] | Train Loss: 25.9574 | Test Acc: 0.6791 | Test AUC: 0.7348 | Time: 0.04s
#   * New best Test AUC: 0.7389 at Epoch 136. Model and DeLong data updated.
# Epoch [136/3500] | Train Loss: 23.8570 | Test Acc: 0.6631 | Test AUC: 0.7389 | Time: 0.04s
#   * New best Test AUC: 0.7397 at Epoch 159. Model and DeLong data updated.
# Epoch [159/3500] | Train Loss: 22.9863 | Test Acc: 0.6738 | Test AUC: 0.7397 | Time: 0.03s
#   * New best Test AUC: 0.7403 at Epoch 160. Model and DeLong data updated.
# Epoch [160/3500] | Train Loss: 22.6992 | Test Acc: 0.6898 | Test AUC: 0.7403 | Time: 0.04s
#   * New best Test AUC: 0.7510 at Epoch 189. Model and DeLong data updated.
# Epoch [189/3500] | Train Loss: 19.6726 | Test Acc: 0.7005 | Test AUC: 0.7510 | Time: 0.04s
#   * New best Test AUC: 0.7582 at Epoch 275. Model and DeLong data updated.
# Epoch [275/3500] | Train Loss: 18.2968 | Test Acc: 0.6898 | Test AUC: 0.7582 | Time: 0.03s
#   * New best Test AUC: 0.7599 at Epoch 311. Model and DeLong data updated.
# Epoch [311/3500] | Train Loss: 13.6202 | Test Acc: 0.7166 | Test AUC: 0.7599 | Time: 0.03s
#   * New best Test AUC: 0.7647 at Epoch 313. Model and DeLong data updated.
# Epoch [313/3500] | Train Loss: 16.6013 | Test Acc: 0.7273 | Test AUC: 0.7647 | Time: 0.03s
#   * New best Test AUC: 0.7657 at Epoch 405. Model and DeLong data updated.
# Epoch [405/3500] | Train Loss: 11.8717 | Test Acc: 0.7112 | Test AUC: 0.7657 | Time: 0.04s
#   * New best Test AUC: 0.7674 at Epoch 426. Model and DeLong data updated.
# Epoch [426/3500] | Train Loss: 10.1169 | Test Acc: 0.7166 | Test AUC: 0.7674 | Time: 0.04s
#   * New best Test AUC: 0.7732 at Epoch 427. Model and DeLong data updated.
# Epoch [427/3500] | Train Loss: 9.4672 | Test Acc: 0.7112 | Test AUC: 0.7732 | Time: 0.04s
#   * New best Test AUC: 0.7762 at Epoch 428. Model and DeLong data updated.
# Epoch [428/3500] | Train Loss: 7.4935 | Test Acc: 0.7112 | Test AUC: 0.7762 | Time: 0.04s
#   * New best Test AUC: 0.7770 at Epoch 444. Model and DeLong data updated.
# Epoch [444/3500] | Train Loss: 10.1264 | Test Acc: 0.7219 | Test AUC: 0.7770 | Time: 0.04s
#   * New best Test AUC: 0.7774 at Epoch 456. Model and DeLong data updated.
# Epoch [456/3500] | Train Loss: 8.9430 | Test Acc: 0.7273 | Test AUC: 0.7774 | Time: 0.03s
#   * New best Test AUC: 0.7834 at Epoch 485. Model and DeLong data updated.
# Epoch [485/3500] | Train Loss: 9.1476 | Test Acc: 0.6845 | Test AUC: 0.7834 | Time: 0.04s
#   * New best Test AUC: 0.7876 at Epoch 599. Model and DeLong data updated.
# Epoch [599/3500] | Train Loss: 6.0542 | Test Acc: 0.7112 | Test AUC: 0.7876 | Time: 0.04s
#   * New best Test AUC: 0.7892 at Epoch 642. Model and DeLong data updated.
# Epoch [642/3500] | Train Loss: 5.7838 | Test Acc: 0.7219 | Test AUC: 0.7892 | Time: 0.04s
#   * New best Test AUC: 0.7936 at Epoch 1062. Model and DeLong data updated.
# Epoch [1062/3500] | Train Loss: 3.7075 | Test Acc: 0.7326 | Test AUC: 0.7936 | Time: 0.04s
#   * New best Test AUC: 0.7944 at Epoch 1063. Model and DeLong data updated.
# Epoch [1063/3500] | Train Loss: 2.9112 | Test Acc: 0.7380 | Test AUC: 0.7944 | Time: 0.04s
#   * New best Test AUC: 0.7949 at Epoch 1064. Model and DeLong data updated.
# Epoch [1064/3500] | Train Loss: 2.6392 | Test Acc: 0.7380 | Test AUC: 0.7949 | Time: 0.04s
#   * New best Test AUC: 0.7956 at Epoch 1291. Model and DeLong data updated.
# Epoch [1291/3500] | Train Loss: 3.0024 | Test Acc: 0.7219 | Test AUC: 0.7956 | Time: 0.03s
#   * New best Test AUC: 0.7966 at Epoch 1293. Model and DeLong data updated.
# Epoch [1293/3500] | Train Loss: 1.8245 | Test Acc: 0.7273 | Test AUC: 0.7966 | Time: 0.03s
#   * New best Test AUC: 0.8056 at Epoch 1294. Model and DeLong data updated.
# Epoch [1294/3500] | Train Loss: 3.1754 | Test Acc: 0.7273 | Test AUC: 0.8056 | Time: 0.03s
#   * New best Test AUC: 0.8066 at Epoch 1383. Model and DeLong data updated.
# Epoch [1383/3500] | Train Loss: 3.0494 | Test Acc: 0.7487 | Test AUC: 0.8066 | Time: 0.04s
#   * New best Test AUC: 0.8075 at Epoch 1445. Model and DeLong data updated.
# Epoch [1445/3500] | Train Loss: 1.9453 | Test Acc: 0.7005 | Test AUC: 0.8075 | Time: 0.04s
#   * New best Test AUC: 0.8076 at Epoch 1446. Model and DeLong data updated.
# Epoch [1446/3500] | Train Loss: 2.0377 | Test Acc: 0.7112 | Test AUC: 0.8076 | Time: 0.04s
#   * New best Test AUC: 0.8099 at Epoch 1626. Model and DeLong data updated.
# Epoch [1626/3500] | Train Loss: 1.5429 | Test Acc: 0.7326 | Test AUC: 0.8099 | Time: 0.04s
#   * New best Test AUC: 0.8120 at Epoch 1627. Model and DeLong data updated.
# Epoch [1627/3500] | Train Loss: 1.3756 | Test Acc: 0.7433 | Test AUC: 0.8120 | Time: 0.04s
#   * New best Test AUC: 0.8140 at Epoch 1628. Model and DeLong data updated.
# Epoch [1628/3500] | Train Loss: 2.1755 | Test Acc: 0.7487 | Test AUC: 0.8140 | Time: 0.04s
#   * New best Test AUC: 0.8177 at Epoch 1629. Model and DeLong data updated.
# Epoch [1629/3500] | Train Loss: 2.0083 | Test Acc: 0.7647 | Test AUC: 0.8177 | Time: 0.04s
#   * New best Test AUC: 0.8203 at Epoch 1630. Model and DeLong data updated.
# Epoch [1630/3500] | Train Loss: 2.9036 | Test Acc: 0.7754 | Test AUC: 0.8203 | Time: 0.04s
#   * New best Test AUC: 0.8222 at Epoch 1631. Model and DeLong data updated.
# Epoch [1631/3500] | Train Loss: 2.6359 | Test Acc: 0.7701 | Test AUC: 0.8222 | Time: 0.04s
#
# --- 训练完成 ---
# 最佳测试集 AUC: 0.8222 (在 Epoch 1631 获得)
# 为DeLong检验准备的最终测试集标签和概率已保存.
# 同时保存为通用文件名: test_labels.npy, test_probabilities.npy
# 训练参数和摘要已保存。

# %%
# main_deep_learning_trainer.py
import os
import argparse
import time
import torch
import torch.nn as nn
import numpy as np
from sklearn.metrics import roc_auc_score, accuracy_score
import pandas as pd

from Transformer import Transformer # 假设其他模型导入也正确
from model_LSTM import Lstm
from model_GRU import GRU
from model_gpt import GPT
import warnings
import sys
from data_utils import load_presplit_data_from_dir
warnings.filterwarnings("ignore", message="Implicit dimension choice for log_softmax has been deprecated.", category=UserWarning, module="torch.nn.modules.module")
# 假设你的 NMTCritierion 在 utilis_data.py 中
# 你需要确保这个导入路径是正确的，或者将 NMTCritierion 的定义复制过来

try:
    from utilis_data import NMTCritierion
    HAS_NMTCriterion = True
except ImportError:
    print("警告: 未找到 utilis_data.NMTCritierion。将使用 nn.CrossEntropyLoss。")
    HAS_NMTCriterion = False
    NMTCritierion = None # 占位

def parse_arguments():
    parser = argparse.ArgumentParser(description="深度学习模型训练脚本 (从预分割数据加载)")
    parser.add_argument('--presplit_data_dir', type=str, required=True,
                        help="包含预分割CSV文件的目录路径。")
    parser.add_argument('--label_column', type=str, default="dead", help="CSV文件中标签列的名称。")
    parser.add_argument('--device', type=str, default='cuda' if torch.cuda.is_available() else 'cpu', help='指定运行设备。')
    parser.add_argument('--seed', type=int, default=42, help='模型训练过程中的随机种子。') # 与原始脚本的seed一致
    
    parser.add_argument('--load_pretrained_model', type=str, default=None,
                    help="预训练模型文件 (.pth) 的路径。如果提供，则加载权重。")
    parser.add_argument('--freeze_backbone', action='store_true',
                    help="如果加载预训练模型，是否冻结骨干网络参数（除分类头外）。")
    
    parser.add_argument('--model_name', type=str, default="Lstm", choices=["Transformer", "Lstm", "GRU", "GPT"], help='选择模型架构。')
    # Transformer specific (Lstm用不到这些，但argparse会处理)
    parser.add_argument('--model_dim', type=int, default=128, help='Transformer/GPT 内部维度。')
    parser.add_argument('--depth', type=int, default=8, help='Transformer 深度。')
    parser.add_argument('--num_heads', type=int, default=8, help='Transformer/GPT 注意力头数。')
    
    # 通用或特定模型
    parser.add_argument('--drop_ratio', type=float, default=0.1, help='模型中的 Dropout 比率。')
    parser.add_argument('--num_layers', type=int, default=2, help="GRU/GPT 的层数 (Lstm层数是固定的)。") # Lstm不直接用这个
    
    parser.add_argument('--lr', type=float, default=5e-4, help='初始学习率。')
    parser.add_argument('--epochs', type=int, default=800, help='训练的总轮数。')
    parser.add_argument('--batch_size', type=int, default=5000, help='数据加载的批量大小。')
    
    parser.add_argument('--output_base_dir', type=str, default="./dl_model_outputs_replication",
                        help="保存输出的主目录。")
    parser.add_argument('--experiment_tag', type=str, default="", help="实验的额外标签。")
    opts = parser.parse_args()
    return opts

def initialize_model(args, num_features):
    # 首先，根据模型名称和参数实例化模型
    if args.model_name == "Lstm":
        print(f"初始化 Lstm模型: factors={num_features}, batch_size={args.batch_size}, drop_ratio={args.drop_ratio}, device={args.device}")
        model = Lstm(
            factors=num_features,
            batch_size=args.batch_size,
            drop_ratio=args.drop_ratio,
            device=args.device
        )
    elif args.model_name == "Transformer":
        print(f"初始化 Transformer模型: input_dim={num_features}, model_dim={args.model_dim}, depth={args.depth}, num_heads={args.num_heads}, drop_ratio={args.drop_ratio}")
        # 确保 Transformer 构造函数与你的 Transformer.py 一致
        model = Transformer(
            input_dim=num_features,
            model_dim=args.model_dim,
            depth=args.depth,
            num_heads=args.num_heads,
            drop_ratio=args.drop_ratio
            # qkv_bias=True, # 根据你的Transformer.py添加其他必要参数
            # attn_drop_ratio=args.drop_ratio,
            # drop_path_ratio=args.drop_path_ratio if hasattr(args, 'drop_path_ratio') else 0.1,
        )
    elif args.model_name == "GRU":
        print(f"初始化 GRU模型: factors={num_features}, batch_size={args.batch_size}, num_layers={args.num_layers}, drop_ratio={args.drop_ratio}, device={args.device}")
        model = GRU(
            factors=num_features,
            batch_size=args.batch_size,
            num_layers=args.num_layers,
            drop_ratio=args.drop_ratio,
            device=args.device
        )
    elif args.model_name == "GPT":
        # 严格遵循原始 train.py 中 GPT 的实例化逻辑
        gpt_actual_input_dim = num_features
        gpt_internal_hidden_dim = num_features # 模型内部工作维度，为了匹配原始 hidden_dim=factors
        gpt_internal_num_heads = 4           # 硬编码自原始 train.py
        gpt_internal_ff_expansion_factor = 128 # 硬编码自原始 train.py

        print(f"初始化 GPT模型 (尝试严格复现原始 train.py 实例化):")
        print(f"  actual_input_dim: {gpt_actual_input_dim}")
        print(f"  hidden_dim: {gpt_internal_hidden_dim}")
        print(f"  num_heads: {gpt_internal_num_heads}")
        print(f"  num_layers: {args.num_layers}")
        print(f"  dropout: {args.drop_ratio}")
        print(f"  ff_expansion_factor: {gpt_internal_ff_expansion_factor}")

        # 确保你的 model_gpt.py 中的 GPT 类 __init__ 签名是这样的：
        # def __init__(self, actual_input_dim, hidden_dim, num_heads, num_layers,
        #              ff_expansion_factor, dropout, max_seq_len=512, device='cuda'):
        # 并且它内部正确使用了 actual_input_dim 来创建一个投影层到 hidden_dim
        model = GPT(
            actual_input_dim=gpt_actual_input_dim,
            hidden_dim=gpt_internal_hidden_dim,
            num_heads=gpt_internal_num_heads,
            num_layers=args.num_layers,
            ff_expansion_factor=gpt_internal_ff_expansion_factor,
            dropout=args.drop_ratio,
            device=args.device
            # max_seq_len 如果需要，也应传递
        )
    else:
        raise ValueError(f"未知的模型名称: {args.model_name}")

    # 将模型移动到设备
    model = model.to(args.device)

    # --- 加载预训练权重逻辑 ---
    if args.load_pretrained_model and hasattr(args, 'load_pretrained_model') and args.load_pretrained_model is not None: # 检查参数是否存在且非None
        if os.path.exists(args.load_pretrained_model):
            print(f"\n加载预训练权重从: {args.load_pretrained_model}")
            try:
                pretrained_state_dict = torch.load(args.load_pretrained_model, map_location=args.device)

                # 处理常见的state_dict包装方式
                if isinstance(pretrained_state_dict, dict):
                    if 'state_dict' in pretrained_state_dict:
                        pretrained_state_dict = pretrained_state_dict['state_dict']
                    elif 'model_state_dict' in pretrained_state_dict:
                        pretrained_state_dict = pretrained_state_dict['model_state_dict']
                    # 如果直接就是 state_dict，则无需处理

                current_model_dict = model.state_dict()

                # --- 确定分类头的名称 ---
                # 这需要根据你每个模型的具体实现来确定
                # 假设 Transformer 的分类头是 'MLP' (基于你原始的 Transformer.py 中的 self.MLP)
                # 假设 Lstm, GRU, GPT 的分类头都叫做 'head' (基于常见的命名)
                # 你需要根据实际情况修改这些名称！
                classifier_head_keyword = None
                if args.model_name == "Transformer":
                    classifier_head_keyword = "MLP." # 加点号确保是模块名的一部分
                elif args.model_name in ["Lstm", "GRU", "GPT"]:
                    # 检查你的模型定义中分类头的真实名称
                    # 假设在这些模型中，最终的线性层或包含最终线性层的Sequential块叫做 'head'
                    if hasattr(model, 'head'):
                        classifier_head_keyword = "head."
                    else:
                        print(f"警告: 模型 {args.model_name} 没有找到名为 'head' 的属性，无法准确排除分类头权重。请检查模型定义。")
                
                if classifier_head_keyword is None and args.model_name != "Transformer": # Transformer 有特例
                     print(f"警告: 未能确定模型 {args.model_name} 的分类头名称，将尝试加载所有匹配的权重。这可能导致分类头也被预训练权重覆盖。")


                state_dict_to_load = {}
                weights_loaded_count = 0
                weights_skipped_shape_mismatch = 0
                weights_skipped_classifier = 0

                for k, v_pretrained in pretrained_state_dict.items():
                    load_this_weight = True
                    if classifier_head_keyword: # 如果我们定义了分类头的关键词
                        if k.startswith(classifier_head_keyword):
                            weights_skipped_classifier += 1
                            load_this_weight = False # 不加载分类头的权重
                    
                    if load_this_weight:
                        if k in current_model_dict:
                            v_current = current_model_dict[k]
                            if v_current.shape == v_pretrained.shape:
                                state_dict_to_load[k] = v_pretrained
                                weights_loaded_count += 1
                            else:
                                print(f"  形状不匹配，跳过加载权重 {k}: 预训练 {v_pretrained.shape}, 当前 {v_current.shape}")
                                weights_skipped_shape_mismatch += 1
                        # else: # 预训练模型中有，但当前模型没有的键，通常可以忽略
                        #     print(f"  权重 {k} 在预训练模型中存在，但在当前模型中不存在，跳过。")
                
                if not state_dict_to_load:
                    print("警告: 没有从预训练模型中找到可加载的匹配权重（非分类头部分）。")
                else:
                    print(f"将从预训练模型加载 {weights_loaded_count} 个参数组。")
                    if weights_skipped_classifier > 0:
                        print(f"  跳过了 {weights_skipped_classifier} 个分类头相关的参数组。")
                    if weights_skipped_shape_mismatch > 0:
                        print(f"  因形状不匹配跳过了 {weights_skipped_shape_mismatch} 个参数组。")
                    
                    current_model_dict.update(state_dict_to_load)
                    # 使用 strict=False 允许当前模型中存在预训练模型没有的键（例如新初始化的分类头）
                    # 也允许预训练模型中存在当前模型没有的键（虽然我们已经通过 k in current_model_dict 过滤了一部分）
                    model.load_state_dict(current_model_dict, strict=False)
                    print("预训练权重加载完成。分类头（如果存在且未被加载）保持其原有初始化。")

                # --- 冻结骨干网络参数 ---
                if args.freeze_backbone and hasattr(args, 'freeze_backbone') and args.freeze_backbone:
                    print("冻结骨干网络参数...")
                    num_frozen = 0
                    num_trainable = 0
                    for name, param in model.named_parameters():
                        freeze_this_param = True
                        if classifier_head_keyword: # 如果我们定义了分类头的关键词
                            if name.startswith(classifier_head_keyword):
                                freeze_this_param = False # 不冻结分类头的参数
                        
                        if freeze_this_param:
                            param.requires_grad = False
                            num_frozen +=1
                        else:
                            param.requires_grad = True # 确保分类头是可训练的
                            print(f"  分类头参数 '{name}' 将保持可训练。")
                            num_trainable +=1
                    print(f"  已冻结 {num_frozen} 组参数。")
                    print(f"  保持可训练 {num_trainable} 组参数 (主要是分类头)。")
            except Exception as e:
                print(f"错误: 加载预训练权重时发生异常: {e}")
                print("将从头开始训练模型。")
        else:
            print(f"警告: 预训练模型文件未找到: {args.load_pretrained_model}。将从头开始训练。")
    else:
        print("未提供预训练模型路径，或未启用预训练加载。模型将从头开始训练。")
        
    return model

def prepare_input_for_model(batch_data, model_name, device):
    # 这个函数与原始 _prepare_input 逻辑一致
    input_features = batch_data['data'].to(device, non_blocking=True)
    targets = batch_data['target'].to(device, non_blocking=True)
    if input_features.ndim == 2:
        input_features = input_features.unsqueeze(1)
    if model_name in ["Lstm", "GRU"]:
        if input_features.shape[1] == 1:
            input_features = input_features.permute(1, 0, 2)
    return input_features, targets

def main():
    args = parse_arguments()

    torch.manual_seed(args.seed)
    np.random.seed(args.seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(args.seed)

    print("\n--- 参数配置 ---")
    for arg, value in sorted(vars(args).items()):
        print(f"  {arg}: {value}")
    print("-" * 30)

    current_time = time.strftime("%Y%m%d-%H%M%S")
    data_source_tag = os.path.basename(os.path.normpath(args.presplit_data_dir))
    experiment_name_parts = [args.model_name, data_source_tag.replace('_split','')]
    if args.experiment_tag: experiment_name_parts.append(args.experiment_tag)
    experiment_name_parts.append(f"trainseed{args.seed}")
    experiment_name_parts.append(current_time)
    experiment_run_name = "_".join(experiment_name_parts)
    experiment_output_dir = os.path.join(args.output_base_dir, experiment_run_name)
    os.makedirs(experiment_output_dir, exist_ok=True)
    print(f"所有输出将保存到: {experiment_output_dir}")

    train_loader, test_loader, n_train, n_test, num_features = load_presplit_data_from_dir(
        presplit_data_dir=args.presplit_data_dir, batch_size=args.batch_size,
        label_column=args.label_column
    )
    print(f"成功从预分割目录加载数据: {args.presplit_data_dir}，特征数: {num_features}")

    model = initialize_model(args, num_features)
    print("\n--- 模型结构 ---")
    print(model)
    print("-" * 30)

    # 严格按照原始 train.py 的优化器设置
    optimizer = torch.optim.Adam(model.parameters(), lr=args.lr, weight_decay=0) # 原始代码 weight_decay=0
    print(f"优化器: Adam, LR: {args.lr}, Weight Decay: 0")

    # 严格按照原始 train.py 的损失函数设置
    if HAS_NMTCriterion:
        label_smoothing_value = 0.3
        criterion = NMTCritierion(label_smoothing=label_smoothing_value).to(args.device)
        print(f"损失函数: NMTCritierion (标签平滑: {label_smoothing_value})")
    else:
        criterion = nn.CrossEntropyLoss().to(args.device)
        print(f"损失函数: nn.CrossEntropyLoss (因为 NMTCritierion 未找到)")


    best_test_auc = 0.0
    best_model_epoch = -1
    final_test_labels_for_delong = None
    final_test_probs_for_delong = None

    print("\n--- 开始训练 ---")
    for epoch in range(args.epochs):
        epoch_start_time = time.time()
        model.train()
        total_train_loss = 0
        for batch_idx, batch in enumerate(train_loader):
            input_features, targets = prepare_input_for_model(batch, args.model_name, args.device)
            optimizer.zero_grad()
            outputs = model(input_features) # outputs 是概率 (因为Lstm模型末尾有Softmax)

            
            if isinstance(criterion, nn.CrossEntropyLoss):
              
                if HAS_NMTCriterion and isinstance(criterion, NMTCritierion):
                    loss = criterion(outputs, targets) # 假设 NMTCritierion 能处理概率或内部有log
                elif isinstance(criterion, nn.CrossEntropyLoss):
                    # 这里是个问题点：CELoss期望logits，但Lstm输出概率
                    # 我们需要 log(probabilities) 作为 CELoss 的近似输入（但不完全等同于logits）
                    # 或者，更标准的是，Lstm模型不应有最后的Softmax
                    print("警告: Lstm模型输出概率，但nn.CrossEntropyLoss期望logits。结果可能不准确。建议修改Lstm模型移除末尾Softmax。")
                    loss = criterion(torch.log(outputs + 1e-9), targets) # 加一个小值避免log(0)
                else: # 其他自定义损失
                    loss = criterion(outputs, targets)

            else: # 默认情况，比如就是 NMTCritierion
                 loss = criterion(outputs, targets)


            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()
        avg_train_loss = total_train_loss / len(train_loader)

        model.eval()
        current_epoch_test_targets_list = []
        current_epoch_test_probs_list = []

        with torch.no_grad():
            for batch in test_loader:
                input_features, targets = prepare_input_for_model(batch, args.model_name, args.device)
                outputs_probs = model(input_features) # Lstm 直接输出概率

                positive_class_probs = outputs_probs[:, 1]
                current_epoch_test_targets_list.extend(targets.cpu().numpy())
                current_epoch_test_probs_list.extend(positive_class_probs.cpu().numpy())

        epoch_targets_np = np.array(current_epoch_test_targets_list)
        epoch_probs_np = np.array(current_epoch_test_probs_list)
        epoch_preds_np = (epoch_probs_np >= 0.5).astype(int)

        test_acc = accuracy_score(epoch_targets_np, epoch_preds_np)
        test_auc = 0.0
        try:
            if len(np.unique(epoch_targets_np)) > 1 and len(epoch_probs_np) > 0:
                test_auc = roc_auc_score(epoch_targets_np, epoch_probs_np)
            else:
                print(f"警告: Epoch {epoch+1} 测试集标签种类不足或概率为空, AUC设为0.0。")
        except ValueError as e:
            print(f"警告: Epoch {epoch+1} 计算AUC时出错 ({e}), AUC设为0.0。")

        epoch_duration = time.time() - epoch_start_time


        if test_auc > best_test_auc:
            best_test_auc = test_auc
            best_model_epoch = epoch + 1
            final_test_labels_for_delong = epoch_targets_np.copy()
            final_test_probs_for_delong = epoch_probs_np.copy()
            torch.save(model.state_dict(), os.path.join(experiment_output_dir, "best_auc_model.pth"))
            print(f"  * New best Test AUC: {best_test_auc:.4f} at Epoch {best_model_epoch}. Model and DeLong data updated.")
            print(f"Epoch [{epoch+1:03d}/{args.epochs:03d}] | "
              f"Train Loss: {avg_train_loss:.4f} | Test Acc: {test_acc:.4f} | "
              f"Test AUC: {test_auc:.4f} | Time: {epoch_duration:.2f}s")
    print("\n--- 训练完成 ---")
    # ... (后续的保存DeLong文件和参数摘要逻辑与之前版本相同) ...
    if best_model_epoch != -1:
        print(f"最佳测试集 AUC: {best_test_auc:.4f} (在 Epoch {best_model_epoch} 获得)")
        if final_test_labels_for_delong is not None and final_test_probs_for_delong is not None:
            np.save(os.path.join(experiment_output_dir, f"{args.model_name}_test_labels_best_auc.npy"), final_test_labels_for_delong)
            np.save(os.path.join(experiment_output_dir, f"{args.model_name}_test_probs_best_auc.npy"), final_test_probs_for_delong)
            print(f"为DeLong检验准备的最终测试集标签和概率已保存.")
            np.save(os.path.join(experiment_output_dir, "test_labels.npy"), final_test_labels_for_delong)
            np.save(os.path.join(experiment_output_dir, "test_probabilities.npy"), final_test_probs_for_delong)
            print(f"同时保存为通用文件名: test_labels.npy, test_probabilities.npy")
    else:
        print("没有在训练过程中记录到有效的最佳AUC模型。")

    args_dict = vars(args)
    args_dict['num_input_features'] = num_features
    args_dict['best_test_auc_achieved'] = best_test_auc
    args_dict['best_model_epoch'] = best_model_epoch
    args_df = pd.DataFrame([args_dict])
    args_df.to_csv(os.path.join(experiment_output_dir, "training_args_summary.csv"), index=False)
    print(f"训练参数和摘要已保存。")



import sys # 确保导入sys模块



if __name__ == '__main__':
    # --- 模拟命令行参数: 测试 Transformer 在 8因子 MIMIC-IV 数据上 (带预训练) ---
    PRETRAINED_LSTM_MODEL_PATH = "./dl_model_outputs_replication/Lstm_mimic3_eICU_8_factors_mimic3eICU-8f-lstm-replication_trainseed42_20250610-043211/best_auc_model.pth"

    # --- 模拟命令行参数: 测试 Lstm 在 8因子 MIMIC-IV 数据上 (带预训练) ---
    sys.argv = [
        'my_script_name_in_notebook.py', # 脚本名占位符
        '--presplit_data_dir', './temp_data_utils_logs/local_8_factors_split', # 8因子 Local 预分割数据目录
        '--model_name', 'Lstm',                                              # 模型名称
        # --- Lstm 相关参数 ---
        '--drop_ratio', '0.1',      # Dropout 比率 (Lstm类使用)
        '--num_layers', '2',        # 命令行参数，但你的Lstm实现可能不使用它
        # --- 通用参数 (严格参考你提供的原始摘要) ---
        '--lr', '0.0005',           # 学习率 (与原始摘要一致)
        '--epochs', '3000',          # Epochs (与原始摘要一致)
        '--batch_size', '5000',     # 批量大小
        '--output_base_dir', './dl_model_outputs_replication', # 输出基础目录
        '--experiment_tag', 'local-8f-lstm-replication',     # 实验标签
        '--seed', '42',             # 随机种子
        '--device', 'cuda',         # 如果可用，使用cuda
        '--label_column', 'dead',    # 标签列名
        '--load_pretrained_model', PRETRAINED_LSTM_MODEL_PATH
    ]
    main()
# Out:
# --- 参数配置 ---
#   batch_size: 5000
#   depth: 8
#   device: cuda
#   drop_ratio: 0.1
#   epochs: 3000
#   experiment_tag: local-8f-lstm-replication
#   freeze_backbone: False
#   label_column: dead
#   load_pretrained_model: ./dl_model_outputs_replication/Lstm_mimic3_eICU_8_factors_mimic3eICU-8f-lstm-replication_trainseed42_20250610-043211/best_auc_model.pth
#   lr: 0.0005
#   model_dim: 128
#   model_name: Lstm
#   num_heads: 8
#   num_layers: 2
#   output_base_dir: ./dl_model_outputs_replication
#   presplit_data_dir: ./temp_data_utils_logs/local_8_factors_split
#   seed: 42
# ------------------------------
# 所有输出将保存到: ./dl_model_outputs_replication/Lstm_local_8_factors_local-8f-lstm-replication_trainseed42_20250610-064404
# 从预分割文件加载数据:
#   训练数据: ./temp_data_utils_logs/local_8_factors_split/split_train_data_seed256.csv
#   测试数据: ./temp_data_utils_logs/local_8_factors_split/split_test_data_seed256.csv
#   - 特征数量: 8
#   - 训练样本数: 435
#   - 测试样本数: 187
# 成功从预分割目录加载数据: ./temp_data_utils_logs/local_8_factors_split，特征数: 8
# 初始化 Lstm模型: factors=8, batch_size=5000, drop_ratio=0.1, device=cuda
#
# 加载预训练权重从: ./dl_model_outputs_replication/Lstm_mimic3_eICU_8_factors_mimic3eICU-8f-lstm-replication_trainseed42_20250610-043211/best_auc_model.pth
# 将从预训练模型加载 12 个参数组。
#   跳过了 4 个分类头相关的参数组。
# 预训练权重加载完成。分类头（如果存在且未被加载）保持其原有初始化。
#
# --- 模型结构 ---
# Lstm(
#   (backbone1): LSTM(8, 192)
#   (backbone2): LSTM(192, 192)
#   (backbone3): LSTM(192, 32)
#   (head): Sequential(
#     (0): Linear(in_features=32, out_features=16, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#     (2): Linear(in_features=16, out_features=2, bias=True)
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Softmax(dim=-1)
#   )
# )
# ------------------------------
# 优化器: Adam, LR: 0.0005, Weight Decay: 0
# 损失函数: NMTCritierion (标签平滑: 0.3)
#
# --- 开始训练 ---
#   * New best Test AUC: 0.5545 at Epoch 1. Model and DeLong data updated.
# Epoch [001/3000] | Train Loss: 42.4808 | Test Acc: 0.5936 | Test AUC: 0.5545 | Time: 0.03s
#   * New best Test AUC: 0.5707 at Epoch 2. Model and DeLong data updated.
# Epoch [002/3000] | Train Loss: 38.6348 | Test Acc: 0.5615 | Test AUC: 0.5707 | Time: 0.03s
#   * New best Test AUC: 0.5787 at Epoch 3. Model and DeLong data updated.
# Epoch [003/3000] | Train Loss: 36.3848 | Test Acc: 0.5775 | Test AUC: 0.5787 | Time: 0.03s
#   * New best Test AUC: 0.5811 at Epoch 4. Model and DeLong data updated.
# Epoch [004/3000] | Train Loss: 35.4988 | Test Acc: 0.5401 | Test AUC: 0.5811 | Time: 0.03s
#   * New best Test AUC: 0.6177 at Epoch 5. Model and DeLong data updated.
# Epoch [005/3000] | Train Loss: 34.8910 | Test Acc: 0.5134 | Test AUC: 0.6177 | Time: 0.03s
# /tmp/ipykernel_991/2140391507.py:135: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pretrained_state_dict = torch.load(args.load_pretrained_model, map_location=args.device)
# /mnt/public/home/zhijiangwan/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
#   * New best Test AUC: 0.6741 at Epoch 6. Model and DeLong data updated.
# Epoch [006/3000] | Train Loss: 34.6400 | Test Acc: 0.5829 | Test AUC: 0.6741 | Time: 0.03s
#   * New best Test AUC: 0.6902 at Epoch 8. Model and DeLong data updated.
# Epoch [008/3000] | Train Loss: 33.2263 | Test Acc: 0.6310 | Test AUC: 0.6902 | Time: 0.03s
#   * New best Test AUC: 0.7130 at Epoch 9. Model and DeLong data updated.
# Epoch [009/3000] | Train Loss: 32.2787 | Test Acc: 0.6203 | Test AUC: 0.7130 | Time: 0.03s
#   * New best Test AUC: 0.7206 at Epoch 11. Model and DeLong data updated.
# Epoch [011/3000] | Train Loss: 31.0179 | Test Acc: 0.6952 | Test AUC: 0.7206 | Time: 0.03s
#   * New best Test AUC: 0.7257 at Epoch 13. Model and DeLong data updated.
# Epoch [013/3000] | Train Loss: 30.9750 | Test Acc: 0.6791 | Test AUC: 0.7257 | Time: 0.03s
#   * New best Test AUC: 0.7307 at Epoch 14. Model and DeLong data updated.
# Epoch [014/3000] | Train Loss: 30.7047 | Test Acc: 0.6791 | Test AUC: 0.7307 | Time: 0.02s
#   * New best Test AUC: 0.7320 at Epoch 21. Model and DeLong data updated.
# Epoch [021/3000] | Train Loss: 30.1900 | Test Acc: 0.6952 | Test AUC: 0.7320 | Time: 0.02s
#   * New best Test AUC: 0.7328 at Epoch 22. Model and DeLong data updated.
# Epoch [022/3000] | Train Loss: 30.1854 | Test Acc: 0.6845 | Test AUC: 0.7328 | Time: 0.02s
#   * New best Test AUC: 0.7336 at Epoch 23. Model and DeLong data updated.
# Epoch [023/3000] | Train Loss: 30.8408 | Test Acc: 0.7059 | Test AUC: 0.7336 | Time: 0.02s
#   * New best Test AUC: 0.7364 at Epoch 24. Model and DeLong data updated.
# Epoch [024/3000] | Train Loss: 29.3922 | Test Acc: 0.6898 | Test AUC: 0.7364 | Time: 0.02s
#   * New best Test AUC: 0.7370 at Epoch 86. Model and DeLong data updated.
# Epoch [086/3000] | Train Loss: 24.0816 | Test Acc: 0.6952 | Test AUC: 0.7370 | Time: 0.02s
#   * New best Test AUC: 0.7393 at Epoch 130. Model and DeLong data updated.
# Epoch [130/3000] | Train Loss: 22.3183 | Test Acc: 0.6791 | Test AUC: 0.7393 | Time: 0.02s
#   * New best Test AUC: 0.7464 at Epoch 244. Model and DeLong data updated.
# Epoch [244/3000] | Train Loss: 17.4337 | Test Acc: 0.6578 | Test AUC: 0.7464 | Time: 0.02s
#   * New best Test AUC: 0.7471 at Epoch 347. Model and DeLong data updated.
# Epoch [347/3000] | Train Loss: 15.3444 | Test Acc: 0.6631 | Test AUC: 0.7471 | Time: 0.02s
#   * New best Test AUC: 0.7474 at Epoch 348. Model and DeLong data updated.
# Epoch [348/3000] | Train Loss: 14.7407 | Test Acc: 0.6684 | Test AUC: 0.7474 | Time: 0.02s
#   * New best Test AUC: 0.7484 at Epoch 349. Model and DeLong data updated.
# Epoch [349/3000] | Train Loss: 14.9924 | Test Acc: 0.6738 | Test AUC: 0.7484 | Time: 0.02s
#   * New best Test AUC: 0.7516 at Epoch 449. Model and DeLong data updated.
# Epoch [449/3000] | Train Loss: 11.2547 | Test Acc: 0.6684 | Test AUC: 0.7516 | Time: 0.02s
#   * New best Test AUC: 0.7524 at Epoch 1176. Model and DeLong data updated.
# Epoch [1176/3000] | Train Loss: 3.2387 | Test Acc: 0.7059 | Test AUC: 0.7524 | Time: 0.02s
#   * New best Test AUC: 0.7546 at Epoch 1183. Model and DeLong data updated.
# Epoch [1183/3000] | Train Loss: 2.4096 | Test Acc: 0.7059 | Test AUC: 0.7546 | Time: 0.02s
#   * New best Test AUC: 0.7586 at Epoch 2316. Model and DeLong data updated.
# Epoch [2316/3000] | Train Loss: 1.6699 | Test Acc: 0.6845 | Test AUC: 0.7586 | Time: 0.02s
#   * New best Test AUC: 0.7591 at Epoch 2563. Model and DeLong data updated.
# Epoch [2563/3000] | Train Loss: 1.5364 | Test Acc: 0.7219 | Test AUC: 0.7591 | Time: 0.02s
#
# --- 训练完成 ---
# 最佳测试集 AUC: 0.7591 (在 Epoch 2563 获得)
# 为DeLong检验准备的最终测试集标签和概率已保存.
# 同时保存为通用文件名: test_labels.npy, test_probabilities.npy
# 训练参数和摘要已保存。

# %%
# main_deep_learning_trainer.py
import os
import argparse
import time
import torch
import torch.nn as nn
import numpy as np
from sklearn.metrics import roc_auc_score, accuracy_score
import pandas as pd

from Transformer import Transformer # 假设其他模型导入也正确
from model_LSTM import Lstm
from model_GRU import GRU
from model_gpt import GPT
import warnings
import sys
from data_utils import load_presplit_data_from_dir
warnings.filterwarnings("ignore", message="Implicit dimension choice for log_softmax has been deprecated.", category=UserWarning, module="torch.nn.modules.module")
# 假设你的 NMTCritierion 在 utilis_data.py 中
# 你需要确保这个导入路径是正确的，或者将 NMTCritierion 的定义复制过来

try:
    from utilis_data import NMTCritierion
    HAS_NMTCriterion = True
except ImportError:
    print("警告: 未找到 utilis_data.NMTCritierion。将使用 nn.CrossEntropyLoss。")
    HAS_NMTCriterion = False
    NMTCritierion = None # 占位

def parse_arguments():
    parser = argparse.ArgumentParser(description="深度学习模型训练脚本 (从预分割数据加载)")
    parser.add_argument('--presplit_data_dir', type=str, required=True,
                        help="包含预分割CSV文件的目录路径。")
    parser.add_argument('--label_column', type=str, default="dead", help="CSV文件中标签列的名称。")
    parser.add_argument('--device', type=str, default='cuda' if torch.cuda.is_available() else 'cpu', help='指定运行设备。')
    parser.add_argument('--seed', type=int, default=42, help='模型训练过程中的随机种子。') # 与原始脚本的seed一致
    
    parser.add_argument('--load_pretrained_model', type=str, default=None,
                    help="预训练模型文件 (.pth) 的路径。如果提供，则加载权重。")
    parser.add_argument('--freeze_backbone', action='store_true',
                    help="如果加载预训练模型，是否冻结骨干网络参数（除分类头外）。")
    
    parser.add_argument('--model_name', type=str, default="Lstm", choices=["Transformer", "Lstm", "GRU", "GPT"], help='选择模型架构。')
    # Transformer specific (Lstm用不到这些，但argparse会处理)
    parser.add_argument('--model_dim', type=int, default=128, help='Transformer/GPT 内部维度。')
    parser.add_argument('--depth', type=int, default=8, help='Transformer 深度。')
    parser.add_argument('--num_heads', type=int, default=8, help='Transformer/GPT 注意力头数。')
    
    # 通用或特定模型
    parser.add_argument('--drop_ratio', type=float, default=0.1, help='模型中的 Dropout 比率。')
    parser.add_argument('--num_layers', type=int, default=2, help="GRU/GPT 的层数 (Lstm层数是固定的)。") # Lstm不直接用这个
    
    parser.add_argument('--lr', type=float, default=5e-4, help='初始学习率。')
    parser.add_argument('--epochs', type=int, default=800, help='训练的总轮数。')
    parser.add_argument('--batch_size', type=int, default=5000, help='数据加载的批量大小。')
    
    parser.add_argument('--output_base_dir', type=str, default="./dl_model_outputs_replication",
                        help="保存输出的主目录。")
    parser.add_argument('--experiment_tag', type=str, default="", help="实验的额外标签。")
    opts = parser.parse_args()
    return opts

def initialize_model(args, num_features):
    # 首先，根据模型名称和参数实例化模型
    if args.model_name == "Lstm":
        print(f"初始化 Lstm模型: factors={num_features}, batch_size={args.batch_size}, drop_ratio={args.drop_ratio}, device={args.device}")
        model = Lstm(
            factors=num_features,
            batch_size=args.batch_size,
            drop_ratio=args.drop_ratio,
            device=args.device
        )
    elif args.model_name == "Transformer":
        print(f"初始化 Transformer模型: input_dim={num_features}, model_dim={args.model_dim}, depth={args.depth}, num_heads={args.num_heads}, drop_ratio={args.drop_ratio}")
        # 确保 Transformer 构造函数与你的 Transformer.py 一致
        model = Transformer(
            input_dim=num_features,
            model_dim=args.model_dim,
            depth=args.depth,
            num_heads=args.num_heads,
            drop_ratio=args.drop_ratio
            # qkv_bias=True, # 根据你的Transformer.py添加其他必要参数
            # attn_drop_ratio=args.drop_ratio,
            # drop_path_ratio=args.drop_path_ratio if hasattr(args, 'drop_path_ratio') else 0.1,
        )
    elif args.model_name == "GRU":
        print(f"初始化 GRU模型: factors={num_features}, batch_size={args.batch_size}, num_layers={args.num_layers}, drop_ratio={args.drop_ratio}, device={args.device}")
        model = GRU(
            factors=num_features,
            batch_size=args.batch_size,
            num_layers=args.num_layers,
            drop_ratio=args.drop_ratio,
            device=args.device
        )
    elif args.model_name == "GPT":
        # 严格遵循原始 train.py 中 GPT 的实例化逻辑
        gpt_actual_input_dim = num_features
        gpt_internal_hidden_dim = num_features # 模型内部工作维度，为了匹配原始 hidden_dim=factors
        gpt_internal_num_heads = 4           # 硬编码自原始 train.py
        gpt_internal_ff_expansion_factor = 128 # 硬编码自原始 train.py

        print(f"初始化 GPT模型 (尝试严格复现原始 train.py 实例化):")
        print(f"  actual_input_dim: {gpt_actual_input_dim}")
        print(f"  hidden_dim: {gpt_internal_hidden_dim}")
        print(f"  num_heads: {gpt_internal_num_heads}")
        print(f"  num_layers: {args.num_layers}")
        print(f"  dropout: {args.drop_ratio}")
        print(f"  ff_expansion_factor: {gpt_internal_ff_expansion_factor}")

        # 确保你的 model_gpt.py 中的 GPT 类 __init__ 签名是这样的：
        # def __init__(self, actual_input_dim, hidden_dim, num_heads, num_layers,
        #              ff_expansion_factor, dropout, max_seq_len=512, device='cuda'):
        # 并且它内部正确使用了 actual_input_dim 来创建一个投影层到 hidden_dim
        model = GPT(
            actual_input_dim=gpt_actual_input_dim,
            hidden_dim=gpt_internal_hidden_dim,
            num_heads=gpt_internal_num_heads,
            num_layers=args.num_layers,
            ff_expansion_factor=gpt_internal_ff_expansion_factor,
            dropout=args.drop_ratio,
            device=args.device
            # max_seq_len 如果需要，也应传递
        )
    else:
        raise ValueError(f"未知的模型名称: {args.model_name}")

    # 将模型移动到设备
    model = model.to(args.device)

    # --- 加载预训练权重逻辑 ---
    if args.load_pretrained_model and hasattr(args, 'load_pretrained_model') and args.load_pretrained_model is not None: # 检查参数是否存在且非None
        if os.path.exists(args.load_pretrained_model):
            print(f"\n加载预训练权重从: {args.load_pretrained_model}")
            try:
                pretrained_state_dict = torch.load(args.load_pretrained_model, map_location=args.device)

                # 处理常见的state_dict包装方式
                if isinstance(pretrained_state_dict, dict):
                    if 'state_dict' in pretrained_state_dict:
                        pretrained_state_dict = pretrained_state_dict['state_dict']
                    elif 'model_state_dict' in pretrained_state_dict:
                        pretrained_state_dict = pretrained_state_dict['model_state_dict']
                    # 如果直接就是 state_dict，则无需处理

                current_model_dict = model.state_dict()

                # --- 确定分类头的名称 ---
                # 这需要根据你每个模型的具体实现来确定
                # 假设 Transformer 的分类头是 'MLP' (基于你原始的 Transformer.py 中的 self.MLP)
                # 假设 Lstm, GRU, GPT 的分类头都叫做 'head' (基于常见的命名)
                # 你需要根据实际情况修改这些名称！
                classifier_head_keyword = None
                if args.model_name == "Transformer":
                    classifier_head_keyword = "MLP." # 加点号确保是模块名的一部分
                elif args.model_name in ["Lstm", "GRU", "GPT"]:
                    # 检查你的模型定义中分类头的真实名称
                    # 假设在这些模型中，最终的线性层或包含最终线性层的Sequential块叫做 'head'
                    if hasattr(model, 'head'):
                        classifier_head_keyword = "head."
                    else:
                        print(f"警告: 模型 {args.model_name} 没有找到名为 'head' 的属性，无法准确排除分类头权重。请检查模型定义。")
                
                if classifier_head_keyword is None and args.model_name != "Transformer": # Transformer 有特例
                     print(f"警告: 未能确定模型 {args.model_name} 的分类头名称，将尝试加载所有匹配的权重。这可能导致分类头也被预训练权重覆盖。")


                state_dict_to_load = {}
                weights_loaded_count = 0
                weights_skipped_shape_mismatch = 0
                weights_skipped_classifier = 0

                for k, v_pretrained in pretrained_state_dict.items():
                    load_this_weight = True
                    if classifier_head_keyword: # 如果我们定义了分类头的关键词
                        if k.startswith(classifier_head_keyword):
                            weights_skipped_classifier += 1
                            load_this_weight = False # 不加载分类头的权重
                    
                    if load_this_weight:
                        if k in current_model_dict:
                            v_current = current_model_dict[k]
                            if v_current.shape == v_pretrained.shape:
                                state_dict_to_load[k] = v_pretrained
                                weights_loaded_count += 1
                            else:
                                print(f"  形状不匹配，跳过加载权重 {k}: 预训练 {v_pretrained.shape}, 当前 {v_current.shape}")
                                weights_skipped_shape_mismatch += 1
                        # else: # 预训练模型中有，但当前模型没有的键，通常可以忽略
                        #     print(f"  权重 {k} 在预训练模型中存在，但在当前模型中不存在，跳过。")
                
                if not state_dict_to_load:
                    print("警告: 没有从预训练模型中找到可加载的匹配权重（非分类头部分）。")
                else:
                    print(f"将从预训练模型加载 {weights_loaded_count} 个参数组。")
                    if weights_skipped_classifier > 0:
                        print(f"  跳过了 {weights_skipped_classifier} 个分类头相关的参数组。")
                    if weights_skipped_shape_mismatch > 0:
                        print(f"  因形状不匹配跳过了 {weights_skipped_shape_mismatch} 个参数组。")
                    
                    current_model_dict.update(state_dict_to_load)
                    # 使用 strict=False 允许当前模型中存在预训练模型没有的键（例如新初始化的分类头）
                    # 也允许预训练模型中存在当前模型没有的键（虽然我们已经通过 k in current_model_dict 过滤了一部分）
                    model.load_state_dict(current_model_dict, strict=False)
                    print("预训练权重加载完成。分类头（如果存在且未被加载）保持其原有初始化。")

                # --- 冻结骨干网络参数 ---
                if args.freeze_backbone and hasattr(args, 'freeze_backbone') and args.freeze_backbone:
                    print("冻结骨干网络参数...")
                    num_frozen = 0
                    num_trainable = 0
                    for name, param in model.named_parameters():
                        freeze_this_param = True
                        if classifier_head_keyword: # 如果我们定义了分类头的关键词
                            if name.startswith(classifier_head_keyword):
                                freeze_this_param = False # 不冻结分类头的参数
                        
                        if freeze_this_param:
                            param.requires_grad = False
                            num_frozen +=1
                        else:
                            param.requires_grad = True # 确保分类头是可训练的
                            print(f"  分类头参数 '{name}' 将保持可训练。")
                            num_trainable +=1
                    print(f"  已冻结 {num_frozen} 组参数。")
                    print(f"  保持可训练 {num_trainable} 组参数 (主要是分类头)。")
            except Exception as e:
                print(f"错误: 加载预训练权重时发生异常: {e}")
                print("将从头开始训练模型。")
        else:
            print(f"警告: 预训练模型文件未找到: {args.load_pretrained_model}。将从头开始训练。")
    else:
        print("未提供预训练模型路径，或未启用预训练加载。模型将从头开始训练。")
        
    return model

def prepare_input_for_model(batch_data, model_name, device):
    # 这个函数与原始 _prepare_input 逻辑一致
    input_features = batch_data['data'].to(device, non_blocking=True)
    targets = batch_data['target'].to(device, non_blocking=True)
    if input_features.ndim == 2:
        input_features = input_features.unsqueeze(1)
    if model_name in ["Lstm", "GRU"]:
        if input_features.shape[1] == 1:
            input_features = input_features.permute(1, 0, 2)
    return input_features, targets

def main():
    args = parse_arguments()

    torch.manual_seed(args.seed)
    np.random.seed(args.seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(args.seed)

    print("\n--- 参数配置 ---")
    for arg, value in sorted(vars(args).items()):
        print(f"  {arg}: {value}")
    print("-" * 30)

    current_time = time.strftime("%Y%m%d-%H%M%S")
    data_source_tag = os.path.basename(os.path.normpath(args.presplit_data_dir))
    experiment_name_parts = [args.model_name, data_source_tag.replace('_split','')]
    if args.experiment_tag: experiment_name_parts.append(args.experiment_tag)
    experiment_name_parts.append(f"trainseed{args.seed}")
    experiment_name_parts.append(current_time)
    experiment_run_name = "_".join(experiment_name_parts)
    experiment_output_dir = os.path.join(args.output_base_dir, experiment_run_name)
    os.makedirs(experiment_output_dir, exist_ok=True)
    print(f"所有输出将保存到: {experiment_output_dir}")

    train_loader, test_loader, n_train, n_test, num_features = load_presplit_data_from_dir(
        presplit_data_dir=args.presplit_data_dir, batch_size=args.batch_size,
        label_column=args.label_column
    )
    print(f"成功从预分割目录加载数据: {args.presplit_data_dir}，特征数: {num_features}")

    model = initialize_model(args, num_features)
    print("\n--- 模型结构 ---")
    print(model)
    print("-" * 30)

    # 严格按照原始 train.py 的优化器设置
    optimizer = torch.optim.Adam(model.parameters(), lr=args.lr, weight_decay=0) # 原始代码 weight_decay=0
    print(f"优化器: Adam, LR: {args.lr}, Weight Decay: 0")

    # 严格按照原始 train.py 的损失函数设置
    if HAS_NMTCriterion:
        label_smoothing_value = 0.3
        criterion = NMTCritierion(label_smoothing=label_smoothing_value).to(args.device)
        print(f"损失函数: NMTCritierion (标签平滑: {label_smoothing_value})")
    else:
        criterion = nn.CrossEntropyLoss().to(args.device)
        print(f"损失函数: nn.CrossEntropyLoss (因为 NMTCritierion 未找到)")


    best_test_auc = 0.0
    best_model_epoch = -1
    final_test_labels_for_delong = None
    final_test_probs_for_delong = None

    print("\n--- 开始训练 ---")
    for epoch in range(args.epochs):
        epoch_start_time = time.time()
        model.train()
        total_train_loss = 0
        for batch_idx, batch in enumerate(train_loader):
            input_features, targets = prepare_input_for_model(batch, args.model_name, args.device)
            optimizer.zero_grad()
            outputs = model(input_features) # outputs 是概率 (因为Lstm模型末尾有Softmax)

            
            if isinstance(criterion, nn.CrossEntropyLoss):
              
                if HAS_NMTCriterion and isinstance(criterion, NMTCritierion):
                    loss = criterion(outputs, targets) # 假设 NMTCritierion 能处理概率或内部有log
                elif isinstance(criterion, nn.CrossEntropyLoss):
                    # 这里是个问题点：CELoss期望logits，但Lstm输出概率
                    # 我们需要 log(probabilities) 作为 CELoss 的近似输入（但不完全等同于logits）
                    # 或者，更标准的是，Lstm模型不应有最后的Softmax
                    print("警告: Lstm模型输出概率，但nn.CrossEntropyLoss期望logits。结果可能不准确。建议修改Lstm模型移除末尾Softmax。")
                    loss = criterion(torch.log(outputs + 1e-9), targets) # 加一个小值避免log(0)
                else: # 其他自定义损失
                    loss = criterion(outputs, targets)

            else: # 默认情况，比如就是 NMTCritierion
                 loss = criterion(outputs, targets)


            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()
        avg_train_loss = total_train_loss / len(train_loader)

        model.eval()
        current_epoch_test_targets_list = []
        current_epoch_test_probs_list = []

        with torch.no_grad():
            for batch in test_loader:
                input_features, targets = prepare_input_for_model(batch, args.model_name, args.device)
                outputs_probs = model(input_features) # Lstm 直接输出概率

                positive_class_probs = outputs_probs[:, 1]
                current_epoch_test_targets_list.extend(targets.cpu().numpy())
                current_epoch_test_probs_list.extend(positive_class_probs.cpu().numpy())

        epoch_targets_np = np.array(current_epoch_test_targets_list)
        epoch_probs_np = np.array(current_epoch_test_probs_list)
        epoch_preds_np = (epoch_probs_np >= 0.5).astype(int)

        test_acc = accuracy_score(epoch_targets_np, epoch_preds_np)
        test_auc = 0.0
        try:
            if len(np.unique(epoch_targets_np)) > 1 and len(epoch_probs_np) > 0:
                test_auc = roc_auc_score(epoch_targets_np, epoch_probs_np)
            else:
                print(f"警告: Epoch {epoch+1} 测试集标签种类不足或概率为空, AUC设为0.0。")
        except ValueError as e:
            print(f"警告: Epoch {epoch+1} 计算AUC时出错 ({e}), AUC设为0.0。")

        epoch_duration = time.time() - epoch_start_time


        if test_auc > best_test_auc:
            best_test_auc = test_auc
            best_model_epoch = epoch + 1
            final_test_labels_for_delong = epoch_targets_np.copy()
            final_test_probs_for_delong = epoch_probs_np.copy()
            torch.save(model.state_dict(), os.path.join(experiment_output_dir, "best_auc_model.pth"))
            print(f"  * New best Test AUC: {best_test_auc:.4f} at Epoch {best_model_epoch}. Model and DeLong data updated.")
            print(f"Epoch [{epoch+1:03d}/{args.epochs:03d}] | "
              f"Train Loss: {avg_train_loss:.4f} | Test Acc: {test_acc:.4f} | "
              f"Test AUC: {test_auc:.4f} | Time: {epoch_duration:.2f}s")
    print("\n--- 训练完成 ---")
    # ... (后续的保存DeLong文件和参数摘要逻辑与之前版本相同) ...
    if best_model_epoch != -1:
        print(f"最佳测试集 AUC: {best_test_auc:.4f} (在 Epoch {best_model_epoch} 获得)")
        if final_test_labels_for_delong is not None and final_test_probs_for_delong is not None:
            np.save(os.path.join(experiment_output_dir, f"{args.model_name}_test_labels_best_auc.npy"), final_test_labels_for_delong)
            np.save(os.path.join(experiment_output_dir, f"{args.model_name}_test_probs_best_auc.npy"), final_test_probs_for_delong)
            print(f"为DeLong检验准备的最终测试集标签和概率已保存.")
            np.save(os.path.join(experiment_output_dir, "test_labels.npy"), final_test_labels_for_delong)
            np.save(os.path.join(experiment_output_dir, "test_probabilities.npy"), final_test_probs_for_delong)
            print(f"同时保存为通用文件名: test_labels.npy, test_probabilities.npy")
    else:
        print("没有在训练过程中记录到有效的最佳AUC模型。")

    args_dict = vars(args)
    args_dict['num_input_features'] = num_features
    args_dict['best_test_auc_achieved'] = best_test_auc
    args_dict['best_model_epoch'] = best_model_epoch
    args_df = pd.DataFrame([args_dict])
    args_df.to_csv(os.path.join(experiment_output_dir, "training_args_summary.csv"), index=False)
    print(f"训练参数和摘要已保存。")



import sys # 确保导入sys模块



if __name__ == '__main__':
    # --- 模拟命令行参数: 测试 Transformer 在 8因子 MIMIC-IV 数据上 (带预训练) ---
    PRETRAINED_GRU_MODEL_PATH = "./dl_model_outputs_replication/GRU_mimic3_eICU_8_factors_mimic3eICU-8f-gru-replication_trainseed42_20250610-050443/best_auc_model.pth"

    # --- 模拟命令行参数: 测试 GRU 在 8因子 MIMIC-IV 数据上 (带预训练) ---
    sys.argv = [
        'my_script_name_in_notebook.py', # 脚本名占位符
        '--presplit_data_dir', './temp_data_utils_logs/local_8_factors_split', # 8因子 Local 预分割数据目录
        '--model_name', 'GRU',                                               # 模型名称
        # --- GRU 特定参数 ---
        '--num_layers', '2',        # GRU 的层数 (与原始摘要一致)
        '--drop_ratio', '0.1',      # Dropout 比率 (与原始摘要一致)
        # --- 通用参数 (严格参考你提供的原始摘要) ---
        '--lr', '0.0005',           # 学习率
        '--epochs', '750',          # Epochs
        '--batch_size', '5000',     # 批量大小
        '--output_base_dir', './dl_model_outputs_replication', # 输出基础目录
        '--experiment_tag', 'local-8f-gru-replication',    # 实验标签
        '--seed', '42',             # 随机种子
        '--device', 'cuda',         # 如果可用，使用cuda
        '--label_column', 'dead',   # 标签列名
        '--load_pretrained_model', PRETRAINED_GRU_MODEL_PATH
    ]
    main()
# Out:
# --- 参数配置 ---
#   batch_size: 5000
#   depth: 8
#   device: cuda
#   drop_ratio: 0.1
#   epochs: 750
#   experiment_tag: local-8f-gru-replication
#   freeze_backbone: False
#   label_column: dead
#   load_pretrained_model: ./dl_model_outputs_replication/GRU_mimic3_eICU_8_factors_mimic3eICU-8f-gru-replication_trainseed42_20250610-050443/best_auc_model.pth
#   lr: 0.0005
#   model_dim: 128
#   model_name: GRU
#   num_heads: 8
#   num_layers: 2
#   output_base_dir: ./dl_model_outputs_replication
#   presplit_data_dir: ./temp_data_utils_logs/local_8_factors_split
#   seed: 42
# ------------------------------
# 所有输出将保存到: ./dl_model_outputs_replication/GRU_local_8_factors_local-8f-gru-replication_trainseed42_20250610-064516
# 从预分割文件加载数据:
#   训练数据: ./temp_data_utils_logs/local_8_factors_split/split_train_data_seed256.csv
#   测试数据: ./temp_data_utils_logs/local_8_factors_split/split_test_data_seed256.csv
#   - 特征数量: 8
#   - 训练样本数: 435
#   - 测试样本数: 187
# 成功从预分割目录加载数据: ./temp_data_utils_logs/local_8_factors_split，特征数: 8
# 初始化 GRU模型: factors=8, batch_size=5000, num_layers=2, drop_ratio=0.1, device=cuda
#
# 加载预训练权重从: ./dl_model_outputs_replication/GRU_mimic3_eICU_8_factors_mimic3eICU-8f-gru-replication_trainseed42_20250610-050443/best_auc_model.pth
# 将从预训练模型加载 12 个参数组。
#   跳过了 4 个分类头相关的参数组。
# 预训练权重加载完成。分类头（如果存在且未被加载）保持其原有初始化。
#
# --- 模型结构 ---
# GRU(
#   (gru): GRU(8, 128, num_layers=2)
#   (head1): Sequential(
#     (0): Linear(in_features=8, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=256, out_features=8, bias=True)
#     (4): ReLU()
#   )
#   (head): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=128, out_features=2, bias=True)
#   )
# )
# ------------------------------
# 优化器: Adam, LR: 0.0005, Weight Decay: 0
# 损失函数: NMTCritierion (标签平滑: 0.3)
#
# --- 开始训练 ---
#   * New best Test AUC: 0.5574 at Epoch 1. Model and DeLong data updated.
# Epoch [001/750] | Train Loss: 36.7647 | Test Acc: 0.4652 | Test AUC: 0.5574 | Time: 0.03s
#   * New best Test AUC: 0.6691 at Epoch 2. Model and DeLong data updated.
# Epoch [002/750] | Train Loss: 35.5564 | Test Acc: 0.4652 | Test AUC: 0.6691 | Time: 0.02s
#   * New best Test AUC: 0.6956 at Epoch 3. Model and DeLong data updated.
# Epoch [003/750] | Train Loss: 34.3656 | Test Acc: 0.4652 | Test AUC: 0.6956 | Time: 0.02s
#   * New best Test AUC: 0.7071 at Epoch 4. Model and DeLong data updated.
# Epoch [004/750] | Train Loss: 33.5433 | Test Acc: 0.4652 | Test AUC: 0.7071 | Time: 0.02s
#   * New best Test AUC: 0.7172 at Epoch 5. Model and DeLong data updated.
# Epoch [005/750] | Train Loss: 32.7443 | Test Acc: 0.4652 | Test AUC: 0.7172 | Time: 0.02s
#   * New best Test AUC: 0.7221 at Epoch 6. Model and DeLong data updated.
# Epoch [006/750] | Train Loss: 32.3040 | Test Acc: 0.4652 | Test AUC: 0.7221 | Time: 0.02s
#   * New best Test AUC: 0.7255 at Epoch 7. Model and DeLong data updated.
# Epoch [007/750] | Train Loss: 31.7558 | Test Acc: 0.4652 | Test AUC: 0.7255 | Time: 0.02s
# /tmp/ipykernel_991/2812379534.py:135: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pretrained_state_dict = torch.load(args.load_pretrained_model, map_location=args.device)
# /mnt/public/home/zhijiangwan/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
#   * New best Test AUC: 0.7282 at Epoch 8. Model and DeLong data updated.
# Epoch [008/750] | Train Loss: 31.2758 | Test Acc: 0.4652 | Test AUC: 0.7282 | Time: 0.02s
#   * New best Test AUC: 0.7284 at Epoch 10. Model and DeLong data updated.
# Epoch [010/750] | Train Loss: 31.1124 | Test Acc: 0.4652 | Test AUC: 0.7284 | Time: 0.02s
#   * New best Test AUC: 0.7285 at Epoch 11. Model and DeLong data updated.
# Epoch [011/750] | Train Loss: 31.1230 | Test Acc: 0.4652 | Test AUC: 0.7285 | Time: 0.02s
#   * New best Test AUC: 0.7290 at Epoch 12. Model and DeLong data updated.
# Epoch [012/750] | Train Loss: 31.0291 | Test Acc: 0.4652 | Test AUC: 0.7290 | Time: 0.02s
#   * New best Test AUC: 0.7299 at Epoch 62. Model and DeLong data updated.
# Epoch [062/750] | Train Loss: 25.4522 | Test Acc: 0.4652 | Test AUC: 0.7299 | Time: 0.02s
#   * New best Test AUC: 0.7310 at Epoch 65. Model and DeLong data updated.
# Epoch [065/750] | Train Loss: 25.1317 | Test Acc: 0.4652 | Test AUC: 0.7310 | Time: 0.02s
#   * New best Test AUC: 0.7328 at Epoch 68. Model and DeLong data updated.
# Epoch [068/750] | Train Loss: 25.2336 | Test Acc: 0.4652 | Test AUC: 0.7328 | Time: 0.02s
#   * New best Test AUC: 0.7329 at Epoch 72. Model and DeLong data updated.
# Epoch [072/750] | Train Loss: 24.8805 | Test Acc: 0.4652 | Test AUC: 0.7329 | Time: 0.02s
#   * New best Test AUC: 0.7334 at Epoch 75. Model and DeLong data updated.
# Epoch [075/750] | Train Loss: 24.6753 | Test Acc: 0.4652 | Test AUC: 0.7334 | Time: 0.02s
#   * New best Test AUC: 0.7339 at Epoch 76. Model and DeLong data updated.
# Epoch [076/750] | Train Loss: 24.3757 | Test Acc: 0.4652 | Test AUC: 0.7339 | Time: 0.02s
#   * New best Test AUC: 0.7340 at Epoch 78. Model and DeLong data updated.
# Epoch [078/750] | Train Loss: 24.7169 | Test Acc: 0.4706 | Test AUC: 0.7340 | Time: 0.02s
#   * New best Test AUC: 0.7354 at Epoch 79. Model and DeLong data updated.
# Epoch [079/750] | Train Loss: 24.4281 | Test Acc: 0.4652 | Test AUC: 0.7354 | Time: 0.02s
#   * New best Test AUC: 0.7363 at Epoch 80. Model and DeLong data updated.
# Epoch [080/750] | Train Loss: 24.4312 | Test Acc: 0.4652 | Test AUC: 0.7363 | Time: 0.02s
#   * New best Test AUC: 0.7371 at Epoch 81. Model and DeLong data updated.
# Epoch [081/750] | Train Loss: 24.2857 | Test Acc: 0.4813 | Test AUC: 0.7371 | Time: 0.02s
#   * New best Test AUC: 0.7374 at Epoch 82. Model and DeLong data updated.
# Epoch [082/750] | Train Loss: 24.4871 | Test Acc: 0.4652 | Test AUC: 0.7374 | Time: 0.02s
#   * New best Test AUC: 0.7380 at Epoch 83. Model and DeLong data updated.
# Epoch [083/750] | Train Loss: 24.3348 | Test Acc: 0.4652 | Test AUC: 0.7380 | Time: 0.02s
#   * New best Test AUC: 0.7387 at Epoch 84. Model and DeLong data updated.
# Epoch [084/750] | Train Loss: 24.0082 | Test Acc: 0.4813 | Test AUC: 0.7387 | Time: 0.02s
#   * New best Test AUC: 0.7401 at Epoch 90. Model and DeLong data updated.
# Epoch [090/750] | Train Loss: 24.0842 | Test Acc: 0.4866 | Test AUC: 0.7401 | Time: 0.02s
#   * New best Test AUC: 0.7402 at Epoch 105. Model and DeLong data updated.
# Epoch [105/750] | Train Loss: 23.2463 | Test Acc: 0.4759 | Test AUC: 0.7402 | Time: 0.02s
#   * New best Test AUC: 0.7417 at Epoch 106. Model and DeLong data updated.
# Epoch [106/750] | Train Loss: 23.1769 | Test Acc: 0.5187 | Test AUC: 0.7417 | Time: 0.02s
#   * New best Test AUC: 0.7423 at Epoch 107. Model and DeLong data updated.
# Epoch [107/750] | Train Loss: 22.6688 | Test Acc: 0.4652 | Test AUC: 0.7423 | Time: 0.02s
#   * New best Test AUC: 0.7433 at Epoch 108. Model and DeLong data updated.
# Epoch [108/750] | Train Loss: 23.2246 | Test Acc: 0.5134 | Test AUC: 0.7433 | Time: 0.02s
#   * New best Test AUC: 0.7436 at Epoch 111. Model and DeLong data updated.
# Epoch [111/750] | Train Loss: 22.5574 | Test Acc: 0.5080 | Test AUC: 0.7436 | Time: 0.02s
#   * New best Test AUC: 0.7444 at Epoch 112. Model and DeLong data updated.
# Epoch [112/750] | Train Loss: 22.1509 | Test Acc: 0.4759 | Test AUC: 0.7444 | Time: 0.02s
#   * New best Test AUC: 0.7454 at Epoch 115. Model and DeLong data updated.
# Epoch [115/750] | Train Loss: 22.1695 | Test Acc: 0.4973 | Test AUC: 0.7454 | Time: 0.02s
#   * New best Test AUC: 0.7476 at Epoch 116. Model and DeLong data updated.
# Epoch [116/750] | Train Loss: 22.0922 | Test Acc: 0.5134 | Test AUC: 0.7476 | Time: 0.02s
#   * New best Test AUC: 0.7492 at Epoch 118. Model and DeLong data updated.
# Epoch [118/750] | Train Loss: 22.3254 | Test Acc: 0.5294 | Test AUC: 0.7492 | Time: 0.02s
#   * New best Test AUC: 0.7501 at Epoch 143. Model and DeLong data updated.
# Epoch [143/750] | Train Loss: 20.9865 | Test Acc: 0.4920 | Test AUC: 0.7501 | Time: 0.02s
#   * New best Test AUC: 0.7503 at Epoch 144. Model and DeLong data updated.
# Epoch [144/750] | Train Loss: 20.3622 | Test Acc: 0.5027 | Test AUC: 0.7503 | Time: 0.02s
#   * New best Test AUC: 0.7514 at Epoch 153. Model and DeLong data updated.
# Epoch [153/750] | Train Loss: 20.1475 | Test Acc: 0.4973 | Test AUC: 0.7514 | Time: 0.02s
#   * New best Test AUC: 0.7517 at Epoch 158. Model and DeLong data updated.
# Epoch [158/750] | Train Loss: 19.7393 | Test Acc: 0.4973 | Test AUC: 0.7517 | Time: 0.02s
#   * New best Test AUC: 0.7520 at Epoch 162. Model and DeLong data updated.
# Epoch [162/750] | Train Loss: 20.1619 | Test Acc: 0.5241 | Test AUC: 0.7520 | Time: 0.02s
#   * New best Test AUC: 0.7522 at Epoch 163. Model and DeLong data updated.
# Epoch [163/750] | Train Loss: 19.8041 | Test Acc: 0.4866 | Test AUC: 0.7522 | Time: 0.02s
#   * New best Test AUC: 0.7534 at Epoch 164. Model and DeLong data updated.
# Epoch [164/750] | Train Loss: 19.3889 | Test Acc: 0.4866 | Test AUC: 0.7534 | Time: 0.02s
#   * New best Test AUC: 0.7538 at Epoch 212. Model and DeLong data updated.
# Epoch [212/750] | Train Loss: 17.9453 | Test Acc: 0.5829 | Test AUC: 0.7538 | Time: 0.02s
#   * New best Test AUC: 0.7544 at Epoch 229. Model and DeLong data updated.
# Epoch [229/750] | Train Loss: 16.2769 | Test Acc: 0.5027 | Test AUC: 0.7544 | Time: 0.02s
#   * New best Test AUC: 0.7554 at Epoch 239. Model and DeLong data updated.
# Epoch [239/750] | Train Loss: 16.3022 | Test Acc: 0.5187 | Test AUC: 0.7554 | Time: 0.02s
#   * New best Test AUC: 0.7571 at Epoch 268. Model and DeLong data updated.
# Epoch [268/750] | Train Loss: 15.2921 | Test Acc: 0.5241 | Test AUC: 0.7571 | Time: 0.02s
#   * New best Test AUC: 0.7586 at Epoch 279. Model and DeLong data updated.
# Epoch [279/750] | Train Loss: 14.9070 | Test Acc: 0.5561 | Test AUC: 0.7586 | Time: 0.02s
#   * New best Test AUC: 0.7605 at Epoch 293. Model and DeLong data updated.
# Epoch [293/750] | Train Loss: 14.6258 | Test Acc: 0.5722 | Test AUC: 0.7605 | Time: 0.02s
#   * New best Test AUC: 0.7622 at Epoch 295. Model and DeLong data updated.
# Epoch [295/750] | Train Loss: 15.0017 | Test Acc: 0.5882 | Test AUC: 0.7622 | Time: 0.02s
#   * New best Test AUC: 0.7628 at Epoch 313. Model and DeLong data updated.
# Epoch [313/750] | Train Loss: 14.8834 | Test Acc: 0.5829 | Test AUC: 0.7628 | Time: 0.02s
#   * New best Test AUC: 0.7629 at Epoch 486. Model and DeLong data updated.
# Epoch [486/750] | Train Loss: 12.9389 | Test Acc: 0.5989 | Test AUC: 0.7629 | Time: 0.02s
#   * New best Test AUC: 0.7633 at Epoch 519. Model and DeLong data updated.
# Epoch [519/750] | Train Loss: 11.6029 | Test Acc: 0.5241 | Test AUC: 0.7633 | Time: 0.02s
#   * New best Test AUC: 0.7637 at Epoch 574. Model and DeLong data updated.
# Epoch [574/750] | Train Loss: 11.3473 | Test Acc: 0.5936 | Test AUC: 0.7637 | Time: 0.02s
#
# --- 训练完成 ---
# 最佳测试集 AUC: 0.7637 (在 Epoch 574 获得)
# 为DeLong检验准备的最终测试集标签和概率已保存.
# 同时保存为通用文件名: test_labels.npy, test_probabilities.npy
# 训练参数和摘要已保存。

# %%
# main_deep_learning_trainer.py
import os
import argparse
import time
import torch
import torch.nn as nn
import numpy as np
from sklearn.metrics import roc_auc_score, accuracy_score
import pandas as pd

from Transformer import Transformer # 假设其他模型导入也正确
from model_LSTM import Lstm
from model_GRU import GRU
from model_gpt import GPT
import warnings
import sys
from data_utils import load_presplit_data_from_dir
warnings.filterwarnings("ignore", message="Implicit dimension choice for log_softmax has been deprecated.", category=UserWarning, module="torch.nn.modules.module")
# 假设你的 NMTCritierion 在 utilis_data.py 中
# 你需要确保这个导入路径是正确的，或者将 NMTCritierion 的定义复制过来

try:
    from utilis_data import NMTCritierion
    HAS_NMTCriterion = True
except ImportError:
    print("警告: 未找到 utilis_data.NMTCritierion。将使用 nn.CrossEntropyLoss。")
    HAS_NMTCriterion = False
    NMTCritierion = None # 占位

def parse_arguments():
    parser = argparse.ArgumentParser(description="深度学习模型训练脚本 (从预分割数据加载)")
    parser.add_argument('--presplit_data_dir', type=str, required=True,
                        help="包含预分割CSV文件的目录路径。")
    parser.add_argument('--label_column', type=str, default="dead", help="CSV文件中标签列的名称。")
    parser.add_argument('--device', type=str, default='cuda' if torch.cuda.is_available() else 'cpu', help='指定运行设备。')
    parser.add_argument('--seed', type=int, default=42, help='模型训练过程中的随机种子。') # 与原始脚本的seed一致
    
    parser.add_argument('--load_pretrained_model', type=str, default=None,
                    help="预训练模型文件 (.pth) 的路径。如果提供，则加载权重。")
    parser.add_argument('--freeze_backbone', action='store_true',
                    help="如果加载预训练模型，是否冻结骨干网络参数（除分类头外）。")
    
    parser.add_argument('--model_name', type=str, default="Lstm", choices=["Transformer", "Lstm", "GRU", "GPT"], help='选择模型架构。')
    # Transformer specific (Lstm用不到这些，但argparse会处理)
    parser.add_argument('--model_dim', type=int, default=128, help='Transformer/GPT 内部维度。')
    parser.add_argument('--depth', type=int, default=8, help='Transformer 深度。')
    parser.add_argument('--num_heads', type=int, default=8, help='Transformer/GPT 注意力头数。')
    
    # 通用或特定模型
    parser.add_argument('--drop_ratio', type=float, default=0.1, help='模型中的 Dropout 比率。')
    parser.add_argument('--num_layers', type=int, default=2, help="GRU/GPT 的层数 (Lstm层数是固定的)。") # Lstm不直接用这个
    
    parser.add_argument('--lr', type=float, default=5e-4, help='初始学习率。')
    parser.add_argument('--epochs', type=int, default=800, help='训练的总轮数。')
    parser.add_argument('--batch_size', type=int, default=5000, help='数据加载的批量大小。')
    
    parser.add_argument('--output_base_dir', type=str, default="./dl_model_outputs_replication",
                        help="保存输出的主目录。")
    parser.add_argument('--experiment_tag', type=str, default="", help="实验的额外标签。")
    opts = parser.parse_args()
    return opts

def initialize_model(args, num_features):
    # 首先，根据模型名称和参数实例化模型
    if args.model_name == "Lstm":
        print(f"初始化 Lstm模型: factors={num_features}, batch_size={args.batch_size}, drop_ratio={args.drop_ratio}, device={args.device}")
        model = Lstm(
            factors=num_features,
            batch_size=args.batch_size,
            drop_ratio=args.drop_ratio,
            device=args.device
        )
    elif args.model_name == "Transformer":
        print(f"初始化 Transformer模型: input_dim={num_features}, model_dim={args.model_dim}, depth={args.depth}, num_heads={args.num_heads}, drop_ratio={args.drop_ratio}")
        # 确保 Transformer 构造函数与你的 Transformer.py 一致
        model = Transformer(
            input_dim=num_features,
            model_dim=args.model_dim,
            depth=args.depth,
            num_heads=args.num_heads,
            drop_ratio=args.drop_ratio
            # qkv_bias=True, # 根据你的Transformer.py添加其他必要参数
            # attn_drop_ratio=args.drop_ratio,
            # drop_path_ratio=args.drop_path_ratio if hasattr(args, 'drop_path_ratio') else 0.1,
        )
    elif args.model_name == "GRU":
        print(f"初始化 GRU模型: factors={num_features}, batch_size={args.batch_size}, num_layers={args.num_layers}, drop_ratio={args.drop_ratio}, device={args.device}")
        model = GRU(
            factors=num_features,
            batch_size=args.batch_size,
            num_layers=args.num_layers,
            drop_ratio=args.drop_ratio,
            device=args.device
        )
    elif args.model_name == "GPT":
        # 严格遵循原始 train.py 中 GPT 的实例化逻辑
        gpt_actual_input_dim = num_features
        gpt_internal_hidden_dim = num_features # 模型内部工作维度，为了匹配原始 hidden_dim=factors
        gpt_internal_num_heads = 4           # 硬编码自原始 train.py
        gpt_internal_ff_expansion_factor = 128 # 硬编码自原始 train.py

        print(f"初始化 GPT模型 (尝试严格复现原始 train.py 实例化):")
        print(f"  actual_input_dim: {gpt_actual_input_dim}")
        print(f"  hidden_dim: {gpt_internal_hidden_dim}")
        print(f"  num_heads: {gpt_internal_num_heads}")
        print(f"  num_layers: {args.num_layers}")
        print(f"  dropout: {args.drop_ratio}")
        print(f"  ff_expansion_factor: {gpt_internal_ff_expansion_factor}")

        # 确保你的 model_gpt.py 中的 GPT 类 __init__ 签名是这样的：
        # def __init__(self, actual_input_dim, hidden_dim, num_heads, num_layers,
        #              ff_expansion_factor, dropout, max_seq_len=512, device='cuda'):
        # 并且它内部正确使用了 actual_input_dim 来创建一个投影层到 hidden_dim
        model = GPT(
            actual_input_dim=gpt_actual_input_dim,
            hidden_dim=gpt_internal_hidden_dim,
            num_heads=gpt_internal_num_heads,
            num_layers=args.num_layers,
            ff_expansion_factor=gpt_internal_ff_expansion_factor,
            dropout=args.drop_ratio,
            device=args.device
            # max_seq_len 如果需要，也应传递
        )
    else:
        raise ValueError(f"未知的模型名称: {args.model_name}")

    # 将模型移动到设备
    model = model.to(args.device)

    # --- 加载预训练权重逻辑 ---
    if args.load_pretrained_model and hasattr(args, 'load_pretrained_model') and args.load_pretrained_model is not None: # 检查参数是否存在且非None
        if os.path.exists(args.load_pretrained_model):
            print(f"\n加载预训练权重从: {args.load_pretrained_model}")
            try:
                pretrained_state_dict = torch.load(args.load_pretrained_model, map_location=args.device)

                # 处理常见的state_dict包装方式
                if isinstance(pretrained_state_dict, dict):
                    if 'state_dict' in pretrained_state_dict:
                        pretrained_state_dict = pretrained_state_dict['state_dict']
                    elif 'model_state_dict' in pretrained_state_dict:
                        pretrained_state_dict = pretrained_state_dict['model_state_dict']
                    # 如果直接就是 state_dict，则无需处理

                current_model_dict = model.state_dict()

                # --- 确定分类头的名称 ---
                # 这需要根据你每个模型的具体实现来确定
                # 假设 Transformer 的分类头是 'MLP' (基于你原始的 Transformer.py 中的 self.MLP)
                # 假设 Lstm, GRU, GPT 的分类头都叫做 'head' (基于常见的命名)
                # 你需要根据实际情况修改这些名称！
                classifier_head_keyword = None
                if args.model_name == "Transformer":
                    classifier_head_keyword = "MLP." # 加点号确保是模块名的一部分
                elif args.model_name in ["Lstm", "GRU", "GPT"]:
                    # 检查你的模型定义中分类头的真实名称
                    # 假设在这些模型中，最终的线性层或包含最终线性层的Sequential块叫做 'head'
                    if hasattr(model, 'head'):
                        classifier_head_keyword = "head."
                    else:
                        print(f"警告: 模型 {args.model_name} 没有找到名为 'head' 的属性，无法准确排除分类头权重。请检查模型定义。")
                
                if classifier_head_keyword is None and args.model_name != "Transformer": # Transformer 有特例
                     print(f"警告: 未能确定模型 {args.model_name} 的分类头名称，将尝试加载所有匹配的权重。这可能导致分类头也被预训练权重覆盖。")


                state_dict_to_load = {}
                weights_loaded_count = 0
                weights_skipped_shape_mismatch = 0
                weights_skipped_classifier = 0

                for k, v_pretrained in pretrained_state_dict.items():
                    load_this_weight = True
                    if classifier_head_keyword: # 如果我们定义了分类头的关键词
                        if k.startswith(classifier_head_keyword):
                            weights_skipped_classifier += 1
                            load_this_weight = False # 不加载分类头的权重
                    
                    if load_this_weight:
                        if k in current_model_dict:
                            v_current = current_model_dict[k]
                            if v_current.shape == v_pretrained.shape:
                                state_dict_to_load[k] = v_pretrained
                                weights_loaded_count += 1
                            else:
                                print(f"  形状不匹配，跳过加载权重 {k}: 预训练 {v_pretrained.shape}, 当前 {v_current.shape}")
                                weights_skipped_shape_mismatch += 1
                        # else: # 预训练模型中有，但当前模型没有的键，通常可以忽略
                        #     print(f"  权重 {k} 在预训练模型中存在，但在当前模型中不存在，跳过。")
                
                if not state_dict_to_load:
                    print("警告: 没有从预训练模型中找到可加载的匹配权重（非分类头部分）。")
                else:
                    print(f"将从预训练模型加载 {weights_loaded_count} 个参数组。")
                    if weights_skipped_classifier > 0:
                        print(f"  跳过了 {weights_skipped_classifier} 个分类头相关的参数组。")
                    if weights_skipped_shape_mismatch > 0:
                        print(f"  因形状不匹配跳过了 {weights_skipped_shape_mismatch} 个参数组。")
                    
                    current_model_dict.update(state_dict_to_load)
                    # 使用 strict=False 允许当前模型中存在预训练模型没有的键（例如新初始化的分类头）
                    # 也允许预训练模型中存在当前模型没有的键（虽然我们已经通过 k in current_model_dict 过滤了一部分）
                    model.load_state_dict(current_model_dict, strict=False)
                    print("预训练权重加载完成。分类头（如果存在且未被加载）保持其原有初始化。")

                # --- 冻结骨干网络参数 ---
                if args.freeze_backbone and hasattr(args, 'freeze_backbone') and args.freeze_backbone:
                    print("冻结骨干网络参数...")
                    num_frozen = 0
                    num_trainable = 0
                    for name, param in model.named_parameters():
                        freeze_this_param = True
                        if classifier_head_keyword: # 如果我们定义了分类头的关键词
                            if name.startswith(classifier_head_keyword):
                                freeze_this_param = False # 不冻结分类头的参数
                        
                        if freeze_this_param:
                            param.requires_grad = False
                            num_frozen +=1
                        else:
                            param.requires_grad = True # 确保分类头是可训练的
                            print(f"  分类头参数 '{name}' 将保持可训练。")
                            num_trainable +=1
                    print(f"  已冻结 {num_frozen} 组参数。")
                    print(f"  保持可训练 {num_trainable} 组参数 (主要是分类头)。")
            except Exception as e:
                print(f"错误: 加载预训练权重时发生异常: {e}")
                print("将从头开始训练模型。")
        else:
            print(f"警告: 预训练模型文件未找到: {args.load_pretrained_model}。将从头开始训练。")
    else:
        print("未提供预训练模型路径，或未启用预训练加载。模型将从头开始训练。")
        
    return model

def prepare_input_for_model(batch_data, model_name, device):
    # 这个函数与原始 _prepare_input 逻辑一致
    input_features = batch_data['data'].to(device, non_blocking=True)
    targets = batch_data['target'].to(device, non_blocking=True)
    if input_features.ndim == 2:
        input_features = input_features.unsqueeze(1)
    if model_name in ["Lstm", "GRU"]:
        if input_features.shape[1] == 1:
            input_features = input_features.permute(1, 0, 2)
    return input_features, targets

def main():
    args = parse_arguments()

    torch.manual_seed(args.seed)
    np.random.seed(args.seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(args.seed)

    print("\n--- 参数配置 ---")
    for arg, value in sorted(vars(args).items()):
        print(f"  {arg}: {value}")
    print("-" * 30)

    current_time = time.strftime("%Y%m%d-%H%M%S")
    data_source_tag = os.path.basename(os.path.normpath(args.presplit_data_dir))
    experiment_name_parts = [args.model_name, data_source_tag.replace('_split','')]
    if args.experiment_tag: experiment_name_parts.append(args.experiment_tag)
    experiment_name_parts.append(f"trainseed{args.seed}")
    experiment_name_parts.append(current_time)
    experiment_run_name = "_".join(experiment_name_parts)
    experiment_output_dir = os.path.join(args.output_base_dir, experiment_run_name)
    os.makedirs(experiment_output_dir, exist_ok=True)
    print(f"所有输出将保存到: {experiment_output_dir}")

    train_loader, test_loader, n_train, n_test, num_features = load_presplit_data_from_dir(
        presplit_data_dir=args.presplit_data_dir, batch_size=args.batch_size,
        label_column=args.label_column
    )
    print(f"成功从预分割目录加载数据: {args.presplit_data_dir}，特征数: {num_features}")

    model = initialize_model(args, num_features)
    print("\n--- 模型结构 ---")
    print(model)
    print("-" * 30)

    # 严格按照原始 train.py 的优化器设置
    optimizer = torch.optim.Adam(model.parameters(), lr=args.lr, weight_decay=0) # 原始代码 weight_decay=0
    print(f"优化器: Adam, LR: {args.lr}, Weight Decay: 0")

    # 严格按照原始 train.py 的损失函数设置
    if HAS_NMTCriterion:
        label_smoothing_value = 0.3
        criterion = NMTCritierion(label_smoothing=label_smoothing_value).to(args.device)
        print(f"损失函数: NMTCritierion (标签平滑: {label_smoothing_value})")
    else:
        criterion = nn.CrossEntropyLoss().to(args.device)
        print(f"损失函数: nn.CrossEntropyLoss (因为 NMTCritierion 未找到)")


    best_test_auc = 0.0
    best_model_epoch = -1
    final_test_labels_for_delong = None
    final_test_probs_for_delong = None

    print("\n--- 开始训练 ---")
    for epoch in range(args.epochs):
        epoch_start_time = time.time()
        model.train()
        total_train_loss = 0
        for batch_idx, batch in enumerate(train_loader):
            input_features, targets = prepare_input_for_model(batch, args.model_name, args.device)
            optimizer.zero_grad()
            outputs = model(input_features) # outputs 是概率 (因为Lstm模型末尾有Softmax)

            
            if isinstance(criterion, nn.CrossEntropyLoss):
              
                if HAS_NMTCriterion and isinstance(criterion, NMTCritierion):
                    loss = criterion(outputs, targets) # 假设 NMTCritierion 能处理概率或内部有log
                elif isinstance(criterion, nn.CrossEntropyLoss):
                    # 这里是个问题点：CELoss期望logits，但Lstm输出概率
                    # 我们需要 log(probabilities) 作为 CELoss 的近似输入（但不完全等同于logits）
                    # 或者，更标准的是，Lstm模型不应有最后的Softmax
                    print("警告: Lstm模型输出概率，但nn.CrossEntropyLoss期望logits。结果可能不准确。建议修改Lstm模型移除末尾Softmax。")
                    loss = criterion(torch.log(outputs + 1e-9), targets) # 加一个小值避免log(0)
                else: # 其他自定义损失
                    loss = criterion(outputs, targets)

            else: # 默认情况，比如就是 NMTCritierion
                 loss = criterion(outputs, targets)


            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()
        avg_train_loss = total_train_loss / len(train_loader)

        model.eval()
        current_epoch_test_targets_list = []
        current_epoch_test_probs_list = []

        with torch.no_grad():
            for batch in test_loader:
                input_features, targets = prepare_input_for_model(batch, args.model_name, args.device)
                outputs_probs = model(input_features) # Lstm 直接输出概率

                positive_class_probs = outputs_probs[:, 1]
                current_epoch_test_targets_list.extend(targets.cpu().numpy())
                current_epoch_test_probs_list.extend(positive_class_probs.cpu().numpy())

        epoch_targets_np = np.array(current_epoch_test_targets_list)
        epoch_probs_np = np.array(current_epoch_test_probs_list)
        epoch_preds_np = (epoch_probs_np >= 0.5).astype(int)

        test_acc = accuracy_score(epoch_targets_np, epoch_preds_np)
        test_auc = 0.0
        try:
            if len(np.unique(epoch_targets_np)) > 1 and len(epoch_probs_np) > 0:
                test_auc = roc_auc_score(epoch_targets_np, epoch_probs_np)
            else:
                print(f"警告: Epoch {epoch+1} 测试集标签种类不足或概率为空, AUC设为0.0。")
        except ValueError as e:
            print(f"警告: Epoch {epoch+1} 计算AUC时出错 ({e}), AUC设为0.0。")

        epoch_duration = time.time() - epoch_start_time


        if test_auc > best_test_auc:
            best_test_auc = test_auc
            best_model_epoch = epoch + 1
            final_test_labels_for_delong = epoch_targets_np.copy()
            final_test_probs_for_delong = epoch_probs_np.copy()
            torch.save(model.state_dict(), os.path.join(experiment_output_dir, "best_auc_model.pth"))
            print(f"  * New best Test AUC: {best_test_auc:.4f} at Epoch {best_model_epoch}. Model and DeLong data updated.")
            print(f"Epoch [{epoch+1:03d}/{args.epochs:03d}] | "
              f"Train Loss: {avg_train_loss:.4f} | Test Acc: {test_acc:.4f} | "
              f"Test AUC: {test_auc:.4f} | Time: {epoch_duration:.2f}s")
    print("\n--- 训练完成 ---")
    # ... (后续的保存DeLong文件和参数摘要逻辑与之前版本相同) ...
    if best_model_epoch != -1:
        print(f"最佳测试集 AUC: {best_test_auc:.4f} (在 Epoch {best_model_epoch} 获得)")
        if final_test_labels_for_delong is not None and final_test_probs_for_delong is not None:
            np.save(os.path.join(experiment_output_dir, f"{args.model_name}_test_labels_best_auc.npy"), final_test_labels_for_delong)
            np.save(os.path.join(experiment_output_dir, f"{args.model_name}_test_probs_best_auc.npy"), final_test_probs_for_delong)
            print(f"为DeLong检验准备的最终测试集标签和概率已保存.")
            np.save(os.path.join(experiment_output_dir, "test_labels.npy"), final_test_labels_for_delong)
            np.save(os.path.join(experiment_output_dir, "test_probabilities.npy"), final_test_probs_for_delong)
            print(f"同时保存为通用文件名: test_labels.npy, test_probabilities.npy")
    else:
        print("没有在训练过程中记录到有效的最佳AUC模型。")

    args_dict = vars(args)
    args_dict['num_input_features'] = num_features
    args_dict['best_test_auc_achieved'] = best_test_auc
    args_dict['best_model_epoch'] = best_model_epoch
    args_df = pd.DataFrame([args_dict])
    args_df.to_csv(os.path.join(experiment_output_dir, "training_args_summary.csv"), index=False)
    print(f"训练参数和摘要已保存。")



import sys # 确保导入sys模块


if __name__ == '__main__':
    # --- 预训练模型路径 ---
    PRETRAINED_GPT_MODEL_PATH = "./dl_model_outputs_replication/GPT_mimic3_eICU_8_factors_mimic3eICU-8f-gpt-replication_trainseed42_20250610-051542/best_auc_model.pth"

    # --- 模拟命令行参数: 测试 GPT 在 8因子 MIMIC-IV 数据上 (带预训练) ---
    sys.argv = [
        'my_script_name_in_notebook.py', # 脚本名占位符
        '--presplit_data_dir', './temp_data_utils_logs/local_8_factors_split', # 8因子 Local 预分割数据目录
        '--model_name', 'GPT',                                               # 模型名称
        # --- GPT 特定参数 (将由 initialize_model 根据原始逻辑处理) ---
        '--num_layers', '1',        # GPT 的层数 (与原始摘要一致)
        '--drop_ratio', '0.1',      # Dropout 比率 (与原始摘要一致)
        # --- 通用参数 (严格参考你提供的原始摘要) ---
        '--lr', '0.005',            # 学习率
        '--epochs', '3500',         # Epochs
        '--batch_size', '5000',     # 批量大小
        '--output_base_dir', './dl_model_outputs_replication', # 输出基础目录
        '--experiment_tag', 'local-8f-gpt-replication',    # 实验标签
        '--seed', '42',             # 随机种子
        '--device', 'cuda',         # 如果可用，使用cuda
        '--label_column', 'dead',   # 标签列名
        '--load_pretrained_model', PRETRAINED_MODEL_PATH,
        # --- 以下参数如果命令行中提供了，initialize_model for GPT 会有特殊处理以复现原始行为 ---
        # '--model_dim', '128', # GPT的hidden_dim会用num_features (8)
        # '--num_heads', '8',   # GPT的num_heads会硬编码为4
    ]
    # --------------------------------------------------------------------

    # 调用你的主函数
    main()
# Out:
# --- 参数配置 ---
#   batch_size: 5000
#   depth: 8
#   device: cuda
#   drop_ratio: 0.1
#   epochs: 3500
#   experiment_tag: local-8f-gpt-replication
#   freeze_backbone: False
#   label_column: dead
#   load_pretrained_model: /mnt/public/home/zhijiangwan/sepsisformer/sepsisformer/model2/dl_model_outputs_replication/Transformer_mimic3_eICU_8_factors_mimic3eICU-8f-transformer-replication_trainseed42_20250610-041619/best_auc_model.pth
#   lr: 0.005
#   model_dim: 128
#   model_name: GPT
#   num_heads: 8
#   num_layers: 1
#   output_base_dir: ./dl_model_outputs_replication
#   presplit_data_dir: ./temp_data_utils_logs/local_8_factors_split
#   seed: 42
# ------------------------------
# 所有输出将保存到: ./dl_model_outputs_replication/GPT_local_8_factors_local-8f-gpt-replication_trainseed42_20250610-064537
# 从预分割文件加载数据:
#   训练数据: ./temp_data_utils_logs/local_8_factors_split/split_train_data_seed256.csv
#   测试数据: ./temp_data_utils_logs/local_8_factors_split/split_test_data_seed256.csv
#   - 特征数量: 8
#   - 训练样本数: 435
#   - 测试样本数: 187
# 成功从预分割目录加载数据: ./temp_data_utils_logs/local_8_factors_split，特征数: 8
# 初始化 GPT模型 (尝试严格复现原始 train.py 实例化):
#   actual_input_dim: 8
#   hidden_dim: 8
#   num_heads: 4
#   num_layers: 1
#   dropout: 0.1
#   ff_expansion_factor: 128
#
# 加载预训练权重从: /mnt/public/home/zhijiangwan/sepsisformer/sepsisformer/model2/dl_model_outputs_replication/Transformer_mimic3_eICU_8_factors_mimic3eICU-8f-transformer-replication_trainseed42_20250610-041619/best_auc_model.pth
# 警告: 没有从预训练模型中找到可加载的匹配权重（非分类头部分）。
#
# --- 模型结构 ---
# GPT(
#   (input_projection): Linear(in_features=8, out_features=8, bias=True)
#   (pos_embedding): Embedding(512, 8)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (decoders): ModuleList(
#     (0): TransformerDecoder(
#       (multihead_attn): MultiHeadAttention(
#         (Q): Linear(in_features=8, out_features=8, bias=True)
#         (K): Linear(in_features=8, out_features=8, bias=True)
#         (V): Linear(in_features=8, out_features=8, bias=True)
#         (fc): Linear(in_features=8, out_features=8, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (dropout1): Dropout(p=0.1, inplace=False)
#       (layer_norm1): LayerNorm((8,), eps=1e-05, elementwise_affine=True)
#       (ff): Sequential(
#         (0): Linear(in_features=8, out_features=1024, bias=True)
#         (1): ReLU()
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=1024, out_features=8, bias=True)
#       )
#       (dropout2): Dropout(p=0.1, inplace=False)
#       (layer_norm2): LayerNorm((8,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (head): Sequential(
#     (0): LayerNorm((8,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=8, out_features=2, bias=True)
#   )
# )
# ------------------------------
# 优化器: Adam, LR: 0.005, Weight Decay: 0
# 损失函数: NMTCritierion (标签平滑: 0.3)
#
# --- 开始训练 ---
# /tmp/ipykernel_991/2040477126.py:135: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pretrained_state_dict = torch.load(args.load_pretrained_model, map_location=args.device)
# /mnt/public/home/zhijiangwan/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
#   * New best Test AUC: 0.4976 at Epoch 1. Model and DeLong data updated.
# Epoch [001/3500] | Train Loss: 59.5254 | Test Acc: 0.4652 | Test AUC: 0.4976 | Time: 0.44s
#   * New best Test AUC: 0.5161 at Epoch 2. Model and DeLong data updated.
# Epoch [002/3500] | Train Loss: 78.0790 | Test Acc: 0.4652 | Test AUC: 0.5161 | Time: 0.02s
#   * New best Test AUC: 0.5301 at Epoch 3. Model and DeLong data updated.
# Epoch [003/3500] | Train Loss: 55.6518 | Test Acc: 0.4652 | Test AUC: 0.5301 | Time: 0.02s
#   * New best Test AUC: 0.5400 at Epoch 4. Model and DeLong data updated.
# Epoch [004/3500] | Train Loss: 41.4369 | Test Acc: 0.4652 | Test AUC: 0.5400 | Time: 0.02s
#   * New best Test AUC: 0.5508 at Epoch 5. Model and DeLong data updated.
# Epoch [005/3500] | Train Loss: 36.7769 | Test Acc: 0.4652 | Test AUC: 0.5508 | Time: 0.02s
#   * New best Test AUC: 0.5576 at Epoch 6. Model and DeLong data updated.
# Epoch [006/3500] | Train Loss: 36.5585 | Test Acc: 0.4652 | Test AUC: 0.5576 | Time: 0.02s
#   * New best Test AUC: 0.5631 at Epoch 7. Model and DeLong data updated.
# Epoch [007/3500] | Train Loss: 38.9921 | Test Acc: 0.4652 | Test AUC: 0.5631 | Time: 0.02s
#   * New best Test AUC: 0.5676 at Epoch 8. Model and DeLong data updated.
# Epoch [008/3500] | Train Loss: 40.2733 | Test Acc: 0.4652 | Test AUC: 0.5676 | Time: 0.02s
#   * New best Test AUC: 0.5692 at Epoch 9. Model and DeLong data updated.
# Epoch [009/3500] | Train Loss: 40.5972 | Test Acc: 0.4652 | Test AUC: 0.5692 | Time: 0.02s
#   * New best Test AUC: 0.5740 at Epoch 10. Model and DeLong data updated.
# Epoch [010/3500] | Train Loss: 39.8948 | Test Acc: 0.4652 | Test AUC: 0.5740 | Time: 0.02s
#   * New best Test AUC: 0.5767 at Epoch 11. Model and DeLong data updated.
# Epoch [011/3500] | Train Loss: 39.1858 | Test Acc: 0.4652 | Test AUC: 0.5767 | Time: 0.02s
#   * New best Test AUC: 0.5790 at Epoch 12. Model and DeLong data updated.
# Epoch [012/3500] | Train Loss: 38.7241 | Test Acc: 0.4652 | Test AUC: 0.5790 | Time: 0.02s
#   * New best Test AUC: 0.5832 at Epoch 13. Model and DeLong data updated.
# Epoch [013/3500] | Train Loss: 37.1020 | Test Acc: 0.4652 | Test AUC: 0.5832 | Time: 0.02s
#   * New best Test AUC: 0.5863 at Epoch 14. Model and DeLong data updated.
# Epoch [014/3500] | Train Loss: 36.8064 | Test Acc: 0.4652 | Test AUC: 0.5863 | Time: 0.02s
#   * New best Test AUC: 0.5885 at Epoch 15. Model and DeLong data updated.
# Epoch [015/3500] | Train Loss: 36.3025 | Test Acc: 0.4652 | Test AUC: 0.5885 | Time: 0.02s
#   * New best Test AUC: 0.5921 at Epoch 16. Model and DeLong data updated.
# Epoch [016/3500] | Train Loss: 36.1593 | Test Acc: 0.4652 | Test AUC: 0.5921 | Time: 0.02s
#   * New best Test AUC: 0.5967 at Epoch 17. Model and DeLong data updated.
# Epoch [017/3500] | Train Loss: 35.6335 | Test Acc: 0.4652 | Test AUC: 0.5967 | Time: 0.02s
#   * New best Test AUC: 0.5995 at Epoch 18. Model and DeLong data updated.
# Epoch [018/3500] | Train Loss: 36.1971 | Test Acc: 0.4652 | Test AUC: 0.5995 | Time: 0.02s
#   * New best Test AUC: 0.6028 at Epoch 19. Model and DeLong data updated.
# Epoch [019/3500] | Train Loss: 36.4600 | Test Acc: 0.4652 | Test AUC: 0.6028 | Time: 0.02s
#   * New best Test AUC: 0.6048 at Epoch 20. Model and DeLong data updated.
# Epoch [020/3500] | Train Loss: 37.1183 | Test Acc: 0.4652 | Test AUC: 0.6048 | Time: 0.02s
#   * New best Test AUC: 0.6067 at Epoch 21. Model and DeLong data updated.
# Epoch [021/3500] | Train Loss: 36.4236 | Test Acc: 0.4652 | Test AUC: 0.6067 | Time: 0.02s
#   * New best Test AUC: 0.6100 at Epoch 22. Model and DeLong data updated.
# Epoch [022/3500] | Train Loss: 36.4004 | Test Acc: 0.4652 | Test AUC: 0.6100 | Time: 0.02s
#   * New best Test AUC: 0.6109 at Epoch 23. Model and DeLong data updated.
# Epoch [023/3500] | Train Loss: 37.1714 | Test Acc: 0.4652 | Test AUC: 0.6109 | Time: 0.02s
#   * New best Test AUC: 0.6116 at Epoch 24. Model and DeLong data updated.
# Epoch [024/3500] | Train Loss: 37.2980 | Test Acc: 0.4652 | Test AUC: 0.6116 | Time: 0.02s
#   * New best Test AUC: 0.6116 at Epoch 25. Model and DeLong data updated.
# Epoch [025/3500] | Train Loss: 36.4149 | Test Acc: 0.4652 | Test AUC: 0.6116 | Time: 0.02s
#   * New best Test AUC: 0.6133 at Epoch 26. Model and DeLong data updated.
# Epoch [026/3500] | Train Loss: 36.6675 | Test Acc: 0.4652 | Test AUC: 0.6133 | Time: 0.02s
#   * New best Test AUC: 0.6139 at Epoch 27. Model and DeLong data updated.
# Epoch [027/3500] | Train Loss: 36.2278 | Test Acc: 0.4652 | Test AUC: 0.6139 | Time: 0.02s
#   * New best Test AUC: 0.6148 at Epoch 28. Model and DeLong data updated.
# Epoch [028/3500] | Train Loss: 35.8760 | Test Acc: 0.4652 | Test AUC: 0.6148 | Time: 0.02s
#   * New best Test AUC: 0.6160 at Epoch 31. Model and DeLong data updated.
# Epoch [031/3500] | Train Loss: 35.6346 | Test Acc: 0.4652 | Test AUC: 0.6160 | Time: 0.02s
#   * New best Test AUC: 0.6179 at Epoch 32. Model and DeLong data updated.
# Epoch [032/3500] | Train Loss: 36.3681 | Test Acc: 0.4652 | Test AUC: 0.6179 | Time: 0.02s
#   * New best Test AUC: 0.6190 at Epoch 33. Model and DeLong data updated.
# Epoch [033/3500] | Train Loss: 35.6465 | Test Acc: 0.4652 | Test AUC: 0.6190 | Time: 0.02s
#   * New best Test AUC: 0.6201 at Epoch 34. Model and DeLong data updated.
# Epoch [034/3500] | Train Loss: 36.4511 | Test Acc: 0.4652 | Test AUC: 0.6201 | Time: 0.02s
#   * New best Test AUC: 0.6225 at Epoch 35. Model and DeLong data updated.
# Epoch [035/3500] | Train Loss: 36.2856 | Test Acc: 0.4652 | Test AUC: 0.6225 | Time: 0.02s
#   * New best Test AUC: 0.6257 at Epoch 36. Model and DeLong data updated.
# Epoch [036/3500] | Train Loss: 35.6284 | Test Acc: 0.4652 | Test AUC: 0.6257 | Time: 0.02s
#   * New best Test AUC: 0.6280 at Epoch 37. Model and DeLong data updated.
# Epoch [037/3500] | Train Loss: 35.7979 | Test Acc: 0.4652 | Test AUC: 0.6280 | Time: 0.02s
#   * New best Test AUC: 0.6305 at Epoch 38. Model and DeLong data updated.
# Epoch [038/3500] | Train Loss: 35.4969 | Test Acc: 0.4652 | Test AUC: 0.6305 | Time: 0.02s
#   * New best Test AUC: 0.6329 at Epoch 39. Model and DeLong data updated.
# Epoch [039/3500] | Train Loss: 35.5187 | Test Acc: 0.4652 | Test AUC: 0.6329 | Time: 0.02s
#   * New best Test AUC: 0.6368 at Epoch 40. Model and DeLong data updated.
# Epoch [040/3500] | Train Loss: 35.3504 | Test Acc: 0.4652 | Test AUC: 0.6368 | Time: 0.02s
#   * New best Test AUC: 0.6399 at Epoch 41. Model and DeLong data updated.
# Epoch [041/3500] | Train Loss: 35.9145 | Test Acc: 0.4652 | Test AUC: 0.6399 | Time: 0.02s
#   * New best Test AUC: 0.6426 at Epoch 42. Model and DeLong data updated.
# Epoch [042/3500] | Train Loss: 35.7024 | Test Acc: 0.4652 | Test AUC: 0.6426 | Time: 0.16s
#   * New best Test AUC: 0.6447 at Epoch 43. Model and DeLong data updated.
# Epoch [043/3500] | Train Loss: 35.8502 | Test Acc: 0.4652 | Test AUC: 0.6447 | Time: 0.02s
#   * New best Test AUC: 0.6452 at Epoch 44. Model and DeLong data updated.
# Epoch [044/3500] | Train Loss: 35.7838 | Test Acc: 0.4652 | Test AUC: 0.6452 | Time: 0.02s
#   * New best Test AUC: 0.6466 at Epoch 45. Model and DeLong data updated.
# Epoch [045/3500] | Train Loss: 35.5101 | Test Acc: 0.4652 | Test AUC: 0.6466 | Time: 0.02s
#   * New best Test AUC: 0.6479 at Epoch 46. Model and DeLong data updated.
# Epoch [046/3500] | Train Loss: 35.5531 | Test Acc: 0.4652 | Test AUC: 0.6479 | Time: 0.02s
#   * New best Test AUC: 0.6494 at Epoch 47. Model and DeLong data updated.
# Epoch [047/3500] | Train Loss: 35.5401 | Test Acc: 0.4652 | Test AUC: 0.6494 | Time: 0.02s
#   * New best Test AUC: 0.6498 at Epoch 48. Model and DeLong data updated.
# Epoch [048/3500] | Train Loss: 35.2359 | Test Acc: 0.4652 | Test AUC: 0.6498 | Time: 0.02s
#   * New best Test AUC: 0.6506 at Epoch 49. Model and DeLong data updated.
# Epoch [049/3500] | Train Loss: 35.6596 | Test Acc: 0.4652 | Test AUC: 0.6506 | Time: 0.02s
#   * New best Test AUC: 0.6528 at Epoch 50. Model and DeLong data updated.
# Epoch [050/3500] | Train Loss: 34.7938 | Test Acc: 0.4652 | Test AUC: 0.6528 | Time: 0.02s
#   * New best Test AUC: 0.6534 at Epoch 51. Model and DeLong data updated.
# Epoch [051/3500] | Train Loss: 35.6169 | Test Acc: 0.4652 | Test AUC: 0.6534 | Time: 0.02s
#   * New best Test AUC: 0.6540 at Epoch 52. Model and DeLong data updated.
# Epoch [052/3500] | Train Loss: 35.7484 | Test Acc: 0.4652 | Test AUC: 0.6540 | Time: 0.03s
#   * New best Test AUC: 0.6554 at Epoch 53. Model and DeLong data updated.
# Epoch [053/3500] | Train Loss: 35.2150 | Test Acc: 0.4652 | Test AUC: 0.6554 | Time: 0.03s
#   * New best Test AUC: 0.6563 at Epoch 54. Model and DeLong data updated.
# Epoch [054/3500] | Train Loss: 35.2982 | Test Acc: 0.4652 | Test AUC: 0.6563 | Time: 0.03s
#   * New best Test AUC: 0.6587 at Epoch 55. Model and DeLong data updated.
# Epoch [055/3500] | Train Loss: 36.0018 | Test Acc: 0.4652 | Test AUC: 0.6587 | Time: 0.02s
#   * New best Test AUC: 0.6610 at Epoch 56. Model and DeLong data updated.
# Epoch [056/3500] | Train Loss: 35.1729 | Test Acc: 0.4652 | Test AUC: 0.6610 | Time: 0.02s
#   * New best Test AUC: 0.6633 at Epoch 58. Model and DeLong data updated.
# Epoch [058/3500] | Train Loss: 35.0611 | Test Acc: 0.4652 | Test AUC: 0.6633 | Time: 0.02s
#   * New best Test AUC: 0.6660 at Epoch 59. Model and DeLong data updated.
# Epoch [059/3500] | Train Loss: 35.1035 | Test Acc: 0.4652 | Test AUC: 0.6660 | Time: 0.02s
#   * New best Test AUC: 0.6689 at Epoch 60. Model and DeLong data updated.
# Epoch [060/3500] | Train Loss: 34.9163 | Test Acc: 0.4652 | Test AUC: 0.6689 | Time: 0.02s
#   * New best Test AUC: 0.6728 at Epoch 61. Model and DeLong data updated.
# Epoch [061/3500] | Train Loss: 35.1488 | Test Acc: 0.4652 | Test AUC: 0.6728 | Time: 0.02s
#   * New best Test AUC: 0.6739 at Epoch 62. Model and DeLong data updated.
# Epoch [062/3500] | Train Loss: 34.6059 | Test Acc: 0.4652 | Test AUC: 0.6739 | Time: 0.02s
#   * New best Test AUC: 0.6764 at Epoch 63. Model and DeLong data updated.
# Epoch [063/3500] | Train Loss: 35.0053 | Test Acc: 0.4652 | Test AUC: 0.6764 | Time: 0.02s
#   * New best Test AUC: 0.6767 at Epoch 64. Model and DeLong data updated.
# Epoch [064/3500] | Train Loss: 34.5117 | Test Acc: 0.4652 | Test AUC: 0.6767 | Time: 0.02s
#   * New best Test AUC: 0.6791 at Epoch 65. Model and DeLong data updated.
# Epoch [065/3500] | Train Loss: 34.7295 | Test Acc: 0.4652 | Test AUC: 0.6791 | Time: 0.02s
#   * New best Test AUC: 0.6803 at Epoch 66. Model and DeLong data updated.
# Epoch [066/3500] | Train Loss: 35.5271 | Test Acc: 0.4652 | Test AUC: 0.6803 | Time: 0.02s
#   * New best Test AUC: 0.6818 at Epoch 67. Model and DeLong data updated.
# Epoch [067/3500] | Train Loss: 34.7725 | Test Acc: 0.4652 | Test AUC: 0.6818 | Time: 0.02s
#   * New best Test AUC: 0.6831 at Epoch 68. Model and DeLong data updated.
# Epoch [068/3500] | Train Loss: 34.7107 | Test Acc: 0.4652 | Test AUC: 0.6831 | Time: 0.02s
#   * New best Test AUC: 0.6838 at Epoch 69. Model and DeLong data updated.
# Epoch [069/3500] | Train Loss: 34.9229 | Test Acc: 0.4652 | Test AUC: 0.6838 | Time: 0.02s
#   * New best Test AUC: 0.6846 at Epoch 70. Model and DeLong data updated.
# Epoch [070/3500] | Train Loss: 34.8707 | Test Acc: 0.4652 | Test AUC: 0.6846 | Time: 0.02s
#   * New best Test AUC: 0.6857 at Epoch 71. Model and DeLong data updated.
# Epoch [071/3500] | Train Loss: 34.7048 | Test Acc: 0.4652 | Test AUC: 0.6857 | Time: 0.02s
#   * New best Test AUC: 0.6882 at Epoch 72. Model and DeLong data updated.
# Epoch [072/3500] | Train Loss: 33.8049 | Test Acc: 0.4652 | Test AUC: 0.6882 | Time: 0.02s
#   * New best Test AUC: 0.6910 at Epoch 73. Model and DeLong data updated.
# Epoch [073/3500] | Train Loss: 34.0730 | Test Acc: 0.4652 | Test AUC: 0.6910 | Time: 0.02s
#   * New best Test AUC: 0.6941 at Epoch 74. Model and DeLong data updated.
# Epoch [074/3500] | Train Loss: 34.1870 | Test Acc: 0.4652 | Test AUC: 0.6941 | Time: 0.02s
#   * New best Test AUC: 0.6949 at Epoch 75. Model and DeLong data updated.
# Epoch [075/3500] | Train Loss: 34.3892 | Test Acc: 0.4652 | Test AUC: 0.6949 | Time: 0.02s
#   * New best Test AUC: 0.6978 at Epoch 76. Model and DeLong data updated.
# Epoch [076/3500] | Train Loss: 34.1886 | Test Acc: 0.4652 | Test AUC: 0.6978 | Time: 0.02s
#   * New best Test AUC: 0.6994 at Epoch 77. Model and DeLong data updated.
# Epoch [077/3500] | Train Loss: 33.6617 | Test Acc: 0.4652 | Test AUC: 0.6994 | Time: 0.02s
#   * New best Test AUC: 0.7020 at Epoch 78. Model and DeLong data updated.
# Epoch [078/3500] | Train Loss: 33.6631 | Test Acc: 0.4652 | Test AUC: 0.7020 | Time: 0.02s
#   * New best Test AUC: 0.7025 at Epoch 79. Model and DeLong data updated.
# Epoch [079/3500] | Train Loss: 34.0045 | Test Acc: 0.4652 | Test AUC: 0.7025 | Time: 0.02s
#   * New best Test AUC: 0.7049 at Epoch 81. Model and DeLong data updated.
# Epoch [081/3500] | Train Loss: 33.6583 | Test Acc: 0.4652 | Test AUC: 0.7049 | Time: 0.02s
#   * New best Test AUC: 0.7053 at Epoch 82. Model and DeLong data updated.
# Epoch [082/3500] | Train Loss: 34.2309 | Test Acc: 0.4652 | Test AUC: 0.7053 | Time: 0.02s
#   * New best Test AUC: 0.7071 at Epoch 83. Model and DeLong data updated.
# Epoch [083/3500] | Train Loss: 33.6420 | Test Acc: 0.4652 | Test AUC: 0.7071 | Time: 0.02s
#   * New best Test AUC: 0.7078 at Epoch 85. Model and DeLong data updated.
# Epoch [085/3500] | Train Loss: 33.2345 | Test Acc: 0.4652 | Test AUC: 0.7078 | Time: 0.02s
#   * New best Test AUC: 0.7084 at Epoch 86. Model and DeLong data updated.
# Epoch [086/3500] | Train Loss: 33.5799 | Test Acc: 0.4652 | Test AUC: 0.7084 | Time: 0.02s
#   * New best Test AUC: 0.7098 at Epoch 87. Model and DeLong data updated.
# Epoch [087/3500] | Train Loss: 33.6899 | Test Acc: 0.4652 | Test AUC: 0.7098 | Time: 0.02s
#   * New best Test AUC: 0.7110 at Epoch 88. Model and DeLong data updated.
# Epoch [088/3500] | Train Loss: 32.8727 | Test Acc: 0.4652 | Test AUC: 0.7110 | Time: 0.02s
#   * New best Test AUC: 0.7111 at Epoch 89. Model and DeLong data updated.
# Epoch [089/3500] | Train Loss: 33.2542 | Test Acc: 0.4652 | Test AUC: 0.7111 | Time: 0.02s
#   * New best Test AUC: 0.7121 at Epoch 90. Model and DeLong data updated.
# Epoch [090/3500] | Train Loss: 32.4705 | Test Acc: 0.4652 | Test AUC: 0.7121 | Time: 0.02s
#   * New best Test AUC: 0.7128 at Epoch 91. Model and DeLong data updated.
# Epoch [091/3500] | Train Loss: 33.5231 | Test Acc: 0.4652 | Test AUC: 0.7128 | Time: 0.02s
#   * New best Test AUC: 0.7129 at Epoch 95. Model and DeLong data updated.
# Epoch [095/3500] | Train Loss: 32.2851 | Test Acc: 0.4652 | Test AUC: 0.7129 | Time: 0.02s
#   * New best Test AUC: 0.7140 at Epoch 96. Model and DeLong data updated.
# Epoch [096/3500] | Train Loss: 33.2432 | Test Acc: 0.4652 | Test AUC: 0.7140 | Time: 0.02s
#   * New best Test AUC: 0.7147 at Epoch 121. Model and DeLong data updated.
# Epoch [121/3500] | Train Loss: 32.8587 | Test Acc: 0.4652 | Test AUC: 0.7147 | Time: 0.02s
#   * New best Test AUC: 0.7159 at Epoch 122. Model and DeLong data updated.
# Epoch [122/3500] | Train Loss: 32.5869 | Test Acc: 0.4652 | Test AUC: 0.7159 | Time: 0.02s
#   * New best Test AUC: 0.7160 at Epoch 127. Model and DeLong data updated.
# Epoch [127/3500] | Train Loss: 32.1316 | Test Acc: 0.4652 | Test AUC: 0.7160 | Time: 0.02s
#   * New best Test AUC: 0.7166 at Epoch 128. Model and DeLong data updated.
# Epoch [128/3500] | Train Loss: 31.9584 | Test Acc: 0.4652 | Test AUC: 0.7166 | Time: 0.02s
#   * New best Test AUC: 0.7170 at Epoch 149. Model and DeLong data updated.
# Epoch [149/3500] | Train Loss: 32.0523 | Test Acc: 0.4652 | Test AUC: 0.7170 | Time: 0.02s
#   * New best Test AUC: 0.7172 at Epoch 150. Model and DeLong data updated.
# Epoch [150/3500] | Train Loss: 32.1030 | Test Acc: 0.4652 | Test AUC: 0.7172 | Time: 0.02s
#   * New best Test AUC: 0.7174 at Epoch 151. Model and DeLong data updated.
# Epoch [151/3500] | Train Loss: 31.8867 | Test Acc: 0.4652 | Test AUC: 0.7174 | Time: 0.02s
#   * New best Test AUC: 0.7179 at Epoch 153. Model and DeLong data updated.
# Epoch [153/3500] | Train Loss: 32.5647 | Test Acc: 0.4652 | Test AUC: 0.7179 | Time: 0.02s
#   * New best Test AUC: 0.7183 at Epoch 158. Model and DeLong data updated.
# Epoch [158/3500] | Train Loss: 31.2424 | Test Acc: 0.4652 | Test AUC: 0.7183 | Time: 0.02s
#   * New best Test AUC: 0.7186 at Epoch 159. Model and DeLong data updated.
# Epoch [159/3500] | Train Loss: 32.3008 | Test Acc: 0.4652 | Test AUC: 0.7186 | Time: 0.02s
#   * New best Test AUC: 0.7192 at Epoch 166. Model and DeLong data updated.
# Epoch [166/3500] | Train Loss: 32.5154 | Test Acc: 0.4652 | Test AUC: 0.7192 | Time: 0.02s
#   * New best Test AUC: 0.7198 at Epoch 167. Model and DeLong data updated.
# Epoch [167/3500] | Train Loss: 32.8089 | Test Acc: 0.4652 | Test AUC: 0.7198 | Time: 0.02s
#   * New best Test AUC: 0.7202 at Epoch 168. Model and DeLong data updated.
# Epoch [168/3500] | Train Loss: 31.7376 | Test Acc: 0.4652 | Test AUC: 0.7202 | Time: 0.02s
#   * New best Test AUC: 0.7257 at Epoch 1319. Model and DeLong data updated.
# Epoch [1319/3500] | Train Loss: 15.4019 | Test Acc: 0.6845 | Test AUC: 0.7257 | Time: 0.02s
#   * New best Test AUC: 0.7277 at Epoch 1343. Model and DeLong data updated.
# Epoch [1343/3500] | Train Loss: 11.9034 | Test Acc: 0.6578 | Test AUC: 0.7277 | Time: 0.02s
#   * New best Test AUC: 0.7283 at Epoch 1430. Model and DeLong data updated.
# Epoch [1430/3500] | Train Loss: 15.0548 | Test Acc: 0.6524 | Test AUC: 0.7283 | Time: 0.02s
#   * New best Test AUC: 0.7284 at Epoch 1459. Model and DeLong data updated.
# Epoch [1459/3500] | Train Loss: 11.2150 | Test Acc: 0.6524 | Test AUC: 0.7284 | Time: 0.02s
#   * New best Test AUC: 0.7322 at Epoch 1566. Model and DeLong data updated.
# Epoch [1566/3500] | Train Loss: 13.3497 | Test Acc: 0.6845 | Test AUC: 0.7322 | Time: 0.02s
#   * New best Test AUC: 0.7425 at Epoch 1570. Model and DeLong data updated.
# Epoch [1570/3500] | Train Loss: 13.8112 | Test Acc: 0.7219 | Test AUC: 0.7425 | Time: 0.02s
#   * New best Test AUC: 0.7460 at Epoch 2043. Model and DeLong data updated.
# Epoch [2043/3500] | Train Loss: 12.8221 | Test Acc: 0.6791 | Test AUC: 0.7460 | Time: 0.02s
#   * New best Test AUC: 0.7479 at Epoch 2178. Model and DeLong data updated.
# Epoch [2178/3500] | Train Loss: 10.4851 | Test Acc: 0.7219 | Test AUC: 0.7479 | Time: 0.02s
#   * New best Test AUC: 0.7482 at Epoch 2184. Model and DeLong data updated.
# Epoch [2184/3500] | Train Loss: 10.2974 | Test Acc: 0.7273 | Test AUC: 0.7482 | Time: 0.02s
#   * New best Test AUC: 0.7534 at Epoch 2322. Model and DeLong data updated.
# Epoch [2322/3500] | Train Loss: 10.5547 | Test Acc: 0.7594 | Test AUC: 0.7534 | Time: 0.02s
#   * New best Test AUC: 0.7607 at Epoch 2456. Model and DeLong data updated.
# Epoch [2456/3500] | Train Loss: 9.6165 | Test Acc: 0.7326 | Test AUC: 0.7607 | Time: 0.02s
#   * New best Test AUC: 0.7689 at Epoch 2936. Model and DeLong data updated.
# Epoch [2936/3500] | Train Loss: 9.5839 | Test Acc: 0.7487 | Test AUC: 0.7689 | Time: 0.02s
#   * New best Test AUC: 0.7737 at Epoch 3068. Model and DeLong data updated.
# Epoch [3068/3500] | Train Loss: 9.8317 | Test Acc: 0.7594 | Test AUC: 0.7737 | Time: 0.02s
#
# --- 训练完成 ---
# 最佳测试集 AUC: 0.7737 (在 Epoch 3068 获得)
# 为DeLong检验准备的最终测试集标签和概率已保存.
# 同时保存为通用文件名: test_labels.npy, test_probabilities.npy
# 训练参数和摘要已保存。
